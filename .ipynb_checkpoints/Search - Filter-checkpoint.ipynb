# %% [markdown]
# ## Filter
# One of the most powerful parameters when defining a search is the ability to filter the results.  While a Query is more of an unstructured approach to search for text within documents, a Filter provides a well-defined structured approach when we know which properties we want to restrict our matching documents.
#
# The following examples will be using some of the popular properties as outlined within the "Properties & Metadata" notebook.  In addition, the selection of these properties was determined based on the discovery techniques used such as metadata and debugging.

# %%
import refinitiv.data as rd
from refinitiv.data.content import search
import pandas as pd
import datetime as dt
import dateutil.relativedelta

# Default session - desktop
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x2c871b594c0 {name='default'}>

# %%
# Display all rows
#pd.set_option('display.max_rows', 10000)
rd.__version__
# Out:
# '1.0.0b9'

# %% [markdown]
# #### Example - Query vs Filter
# As you become more familiar with Search, you will realize there are a number of different paths you can take to arrive at the same destination.

# %%
# Retrieve the document(s) for a specific ISIN using a Query.
response=search.Definition(
    view = search.SearchViews.INSTRUMENTS,
    query = 'US046353AQ14',
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
).get_data()
response.data.df
# Out:
#                                        DocumentTitle         RIC  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bo...  046353AQ1=
#
#            ISIN      CUSIP    SEDOL       PermID
# 0  US046353AQ14  046353AQ1  BF4SNM7  46645702869

# %%
# Retrieve the document(s) for the same ISIN using a Filter
response=search.Definition(
    view = search.SearchViews.INSTRUMENTS,
    filter = "ISIN eq 'US046353AQ14'",
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
).get_data()
response.data.df
# Out:
#                                        DocumentTitle         RIC  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bo...  046353AQ1=
#
#            ISIN      CUSIP    SEDOL       PermID
# 0  US046353AQ14  046353AQ1  BF4SNM7  46645702869

# %% [markdown]
# #### Special Properties

# %%
# If you are provided a code but are not sure if the code is an ISIN, SEDOL, CUSIP etc, 
# try using the 'CodeResolutionBase' property.
response=search.Definition(
    view = search.SearchViews.INSTRUMENTS,
    filter = "code eq '046353AQ1'",               # Use the CUSIP for the same instrument
    #filter = "CodeResolutionBase eq 'BF4SNM7'",   # Use the SEDOL
    select = 'DocumentTitle, RIC, ISIN, CUSIP, SEDOL, PermID'
).get_data()
response.data.df
# Out:
#                                                                             DocumentTitle  \
# 0  AstraZeneca PLC, Plain Vanilla Fixed Coupon Bond, TRACE Eligible AZN 2.375 12-Jun-2022
#
#           RIC          ISIN      CUSIP    SEDOL       PermID
# 0  046353AQ1=  US046353AQ14  046353AQ1  BF4SNM7  46645702869

# %%
help(search.Definition)
# Out:
# Help on class Definition in module refinitiv.data._data.content.search.search:
#
# class Definition(refinitiv.data._data.content._content_provider.ContentProviderLayer)
#  |  Definition(query: str = None, view: refinitiv.data._data.content.search.search_view_type.SearchViews = <SearchViews.SEARCH_ALL: 'SearchAll'>, filter: str = None, order_by: str = None, boost: str = None, select: str = None, top: int = 10, skip: int = 0, group_by: str = None, group_count: int = 3, navigators: str = None, features: str = None, scope: str = None, terms: str = None, extended_params: dict = None)
#  |
#  |  This class describe parameters to retrieve data for search.
#  |
#  |  Parameters
#  |  ----------
#  |  query: str, optional
#  |      Keyword argument for view
#  |
#  |  view: SearchViews, optional
#  |      The view for searching see at SearchViews enum.
#  |      Default: SearchViews.SEARCH_ALL
#  |
#  |  filter: str, optional
#  |      Where query is for unstructured end-user-oriented restriction, filter is for
#  |      structured programmatic restriction.
#  |
#  |  order_by: str, optional
#  |      Defines the order in which matching documents should be returned.
#  |
#  |  boost: str, optional
#  |      This argument supports exactly the same predicate expression syntax as filter,
#  |      but where filter restricts which documents are matched at all,
#  |      boost just applies a large scoring boost to documents it matches,
#  |      which will almost always guarantee that they appear at the top of the results.
#  |
#  |  select: str, optional
#  |      A comma-separated list of the properties of a document to be returned in the response.
#  |
#  |  top: int, optional
#  |      the maximum number of documents to retrieve. Must be non-negative.
#  |      default: 10
#  |
#  |  skip: int, optional
#  |      The number of documents to skip in the sorted result set before returning the
#  |      next top.
#  |
#  |  group_by: str, optional
#  |      If specified, this must name a single Groupable property.
#  |      returned documents are grouped into buckets based on their value for this
#  |      property.
#  |
#  |  group_count: str, optional
#  |      When supplied in combination with group_by, sets the maximum number of documents
#  |      to be returned per bucket.
#  |      default: 3
#  |
#  |  navigators: str, optional
#  |      This can name one or more properties, separated by commas, each of which must
#  |      be Navigable.
#  |
#  |  extended_params : dict, optional
#  |      other parameters can be provided if necessary
#  |
#  |  Examples
#  |  --------
#  |  >>> from refinitiv.data.content import search
#  |  >>> definition = search.Definition(query="cfo", view=search.SearchViews.PEOPLE)
#  |
#  |  Method resolution order:
#  |      Definition
#  |      refinitiv.data._data.content._content_provider.ContentProviderLayer
#  |      refinitiv.data._data.delivery.data._data_provider.DataProviderLayer
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, query: str = None, view: refinitiv.data._data.content.search.search_view_type.SearchViews = <SearchViews.SEARCH_ALL: 'SearchAll'>, filter: str = None, order_by: str = None, boost: str = None, select: str = None, top: int = 10, skip: int = 0, group_by: str = None, group_count: int = 3, navigators: str = None, features: str = None, scope: str = None, terms: str = None, extended_params: dict = None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from refinitiv.data._data.delivery.data._data_provider.DataProviderLayer:
#  |
#  |  get_data(self, session=None, on_response=None, **kwargs)
#  |      Returns a response to the data platform
#  |
#  |      Parameters
#  |      ----------
#  |      session : Session, optional
#  |          Means default session would be used
#  |      on_response : Callable, optional
#  |          Callable object to process retrieved data
#  |
#  |      Returns
#  |      -------
#  |      Response
#  |
#  |      Raises
#  |      ------
#  |      AttributeError
#  |          If user didn't set default session.
#  |
#  |  async get_data_async(self, session=None, on_response=None, **kwargs)
#  |      Returns a response asynchronously to the data platform
#  |
#  |      Parameters
#  |      ----------
#  |      session : Session, optional
#  |          Means default session would be used
#  |      on_response : Callable, optional
#  |          Callable object to process retrieved data
#  |
#  |      Returns
#  |      -------
#  |      Response
#  |
#  |      Raises
#  |      ------
#  |      AttributeError
#  |          If user didn't set default session.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from refinitiv.data._data.delivery.data._data_provider.DataProviderLayer:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %% [markdown]
# #### Example - Apple Equities

# %%
# Within the view (EquityQuotes), select all documents where the term 'AAPL' is within the ticker symbol.  For each, 
# ensure the type of asset is an 'equity' and that each asset is in an active state.  I chose to filter out the 
# AssetState of 'DC' (De-activated) as my criteria. By default, the top 10 results are presented.
#
# Note: An alternative to "AssetType eq 'equity'" could be to use: "RCSAssetCategoryLeaf eq 'Ordinary Share'"
response=search.Definition(
    view = search.SearchViews.EQUITY_QUOTES,
    filter = "AssetType eq 'equity' and AssetState ne 'DC' and TickerSymbol eq 'AAPL'",
    select = "RIC, CompositeDescriptiveName, ExchangeCode, ExchangeName, AssetType"
).get_data()
response.data.df
# Out:
#            RIC  \
# 0       AAPL.O
# 1  AAPLEUR.xbo
# 2      AAPL.OQ
# 3      AAPL.DG
# 4       AAPL.Z
# 5       AAPL.B
# 6     AAPLE.MI
# 7     AAPL.CCP
# 8      AAPL.DY
# 9      AAPL.PH
#
#                                          CompositeDescriptiveName  \
# 0                                         Apple Ord Shs APPLE ORD
# 1                               Apple Ord Shs APPLE ORD APPLE INC
# 2                                         Apple Ord Shs APPLE ORD
# 3                                         Apple Ord Shs APPLE ORD
# 4                               Apple Ord Shs APPLE ORD APPLE INC
# 5                                         Apple Ord Shs APPLE ORD
# 6                                         Apple Ord Shs APPLE ORD
# 7  Apple 100 CDR Representing 12 Ord Shs APPLE 100 CDR REP 12 ORD
# 8                                         Apple Ord Shs APPLE ORD
# 9                               Apple Ord Shs APPLE ORD APPLE INC
#
#   ExchangeCode                                        ExchangeName AssetType
# 0          NSQ                   NASDAQ Global Select Consolidated  [EQUITY]
# 1          XBO                MiFID Composite Cross Market Service  [EQUITY]
# 2          NSM          NASDAQ Stock Exchange Global Select Market  [EQUITY]
# 3          GCD    Cboe EDGX Exchange - Nasdaq Global Select Market  [EQUITY]
# 4          GCZ     Cboe BZX Exchange - Nasdaq Global Select Market  [EQUITY]
# 5          GSB  Boston SE when trading NASDAQ Global Select Market  [EQUITY]
# 6          MIL                                Milan Stock Exchange  [EQUITY]
# 7          CAQ                      Canadian Composite Quote/Trade  [EQUITY]
# 8          GDA    Cboe EDGA Exchange - Nasdaq Global Select Market  [EQUITY]
# 9          GSX                NASDAQ OMX PHLX Global Select Market  [EQUITY]

# %% [markdown]
# #### Example - Vessels
# List all Very Large Gas Containers (VLGC) that are in service within the last week.

# %%
# Build date range expression for the location of the vessel for the last 7 days
date_7_days_ago = dt.datetime.today() - dateutil.relativedelta.relativedelta(days=7)
date_range = f'LocationTimestamp ge {date_7_days_ago.strftime("%Y-%m-%d")} and \
               LocationTimestamp lt {dt.datetime.today().strftime("%Y-%m-%d")}'

# %%
# Show the location of each vessel and some general details such as location, destination and coordinates.
# If available, show the top 100 hits.
response=search.Definition(
    view = search.SearchViews.VESSEL_PHYSICAL_ASSETS,
    filter = f"RCSAssetTypeLeaf eq 'VLGC' and VesselStatus eq 'IN SERVICE' and {date_range}",
    select = 'RIC, SynonymSearchAll, DTSource, LocationTimestamp, IMO,Latitude, Longitude, LocationDestination',
    top=100
).get_data()
response.data.df
# Out:
#               RIC  \
# 0  C}KY7309466539
# 1  C}KY7309473669
# 2  C}KL7309478067
# 3  C}KY7309495163
# 4  C}KY7309636853
# 5  C}KY7309843619
# 6  C}KY7309466419
# 7  C}KY7309466850
#
#                                                                 SynonymSearchAll  \
# 0  Chinese Korean Liquefied Petroleum Gas Very Large Gas Carrier Thai Vietnamese
# 1            India Liquefied Petroleum Gas Very Large Gas Carrier Korean Chinese
# 2                  Liquefied Petroleum Gas Very Large Gas Carrier Korean Chinese
# 3                                 Liquefied Petroleum Gas Very Large Gas Carrier
# 4                                 Liquefied Petroleum Gas Very Large Gas Carrier
# 5                        Liquefied Petroleum Gas Very Large Gas Carrier Japanese
# 6                                 Liquefied Petroleum Gas Very Large Gas Carrier
# 7                         Chinese Liquefied Petroleum Gas Very Large Gas Carrier
#
#                                                         DTSource  \
# 0                             South China Sea|Canton Tanker Zone
# 1       Andaman Sea|Singapore Tanker Zone|Great Channel Waypoint
# 2                                 Java Sea|Singapore Tanker Zone
# 3     Gulf of Oman|Arabian Gulf Tanker Zone|United Arab Emirates
# 4                                      Red Sea|Yanbu Tanker Zone
# 5             Pacific Ocean (Central America)|Panama Tanker Zone
# 6                          Gulf of Oman|Arabian Gulf Tanker Zone
# 7  Guangdong|South China Sea|Canton Tanker Zone|China (Mainland)
#
#           LocationTimestamp      IMO   Latitude   Longitude  \
# 0  2022-04-17T20:52:36.000Z  9002908     20.215  115.866669
# 1  2022-04-18T19:59:44.000Z  9114581   6.197838   95.405022
# 2  2022-04-15T14:26:37.000Z  9172636   1.353847  104.408623
# 3  2022-04-18T21:42:21.000Z  9387750  24.163034   52.726025
# 4  2022-04-15T18:36:05.000Z  9719496  17.057825   42.115723
# 5  2022-04-16T17:14:37.000Z  9749788  10.944246  -93.079643
# 6  2022-04-15T23:31:38.000Z  9000883  25.661646   54.992416
# 7  2022-04-16T03:17:45.000Z  9007386  23.083216  113.478203
#
#                LocationDestination
# 0                VN VUT [Vung Tau]
# 1   LIANYUNGAN,CHINA [Lianyungang]
# 2                  CNLKU [Longkou]
# 3     RUWAIS [Jebel Dhanna/Ruwais]
# 4        JIZAN [Gizan Marine Port]
# 5                   JP CHB [Chiba]
# 6  SHARJAH [Mina Khalid (Sharjah)]
# 7                  GUANGCHOU,CHINA

# %% [markdown]
# #### Example - Floating Rate Notes
# Retrieve all floating rate notes (floating coupon) in the healthcare sector which are issued in Euros.  For each, ensure the coupon rate is great than 2 and our Moody's rating is greater than 'Baa1'.
#
# To determine the rating, we apply the following logic utilizing the RatingsScope property - which is a nested property providing additional details:
#
# - RatingsScope(RatingType eq 'MIS' and CurrentRatingRank lt 10)
#
# The RatingType of 'MIS' refers to the "Moody's Long-term Issuer Rating".
# The CurrentRatingRank < 10 instructs search to look for ratings less than 10 ('Baa1').  **Note**: The lower the rank, the better the rating.

# %%
response=search.Definition(
    view = search.SearchViews.GOV_CORP_INSTRUMENTS,
    filter = "CouponRate gt 2 and \
              RatingsScope(RatingType eq 'MIS' and CurrentRatingRank lt 10) and \
              RCSCouponTypeName eq 'Floating Coupon' and \
              IsActive eq true and \
              RCSTRBC2012Name eq 'Healthcare' and \
              RCSCurrencyLeaf xeq 'Euro'",
    select = "CouponCurrency, IssuerName, IssueDate, RIC, CouponRate, ISIN, Ticker, RCSTRBC2012Leaf, MaturityDate, AssetState",   
).get_data()
response.data.df
# Out:
#   CouponCurrency IssuerName                 IssueDate                RIC  \
# 0            EUR  Sanofi FR  1983-07-01T00:00:00.000Z      FR0000140022=
# 1            EUR  Sanofi FR  1987-10-01T00:00:00.000Z  FR0000047656=AURO
#
#    CouponRate          ISIN Ticker        RCSTRBC2012Leaf
# 0        15.5  FR0000140022   SASY  Pharmaceuticals (NEC)
# 1        15.5  FR0000047656   SASY  Pharmaceuticals (NEC)

# %% [markdown]
# #### Example - Outstanding Green Bonds
# List the outstanding Green Bonds for Telefonica.

# %%
response=search.Definition(
    view = search.SearchViews.GOV_CORP_INSTRUMENTS,
    filter = "IssuerName eq 'Telefonica' and IsGreenBond eq true",
    select = "IssuerName, DocumentTitle, RIC, CouponRate, ISIN, IssuerTicker, DebtTypeDescription, EOMAmountOutstanding, FaceOutstanding"
).get_data()
response.data.df
# Out:
#          IssuerName  \
# 0  Telefonica Europ
# 1   Telefonica Emis
#
#                                                                       DocumentTitle  \
# 0                                             Telefonica Europe BV, Bond, TEF 2.502
# 1  Telefonica Emisiones SAU, Plain Vanilla Fixed Coupon Bond, TEF 1.069 05-Feb-2024
#
#             RIC  CouponRate          ISIN IssuerTicker  \
# 0  ES210981985=       2.502  XS2109819859        TEFBV
# 1  ES194600445=       1.069  XS1946004451       TEFEMI
#
#         DebtTypeDescription  EOMAmountOutstanding  FaceOutstanding
# 0  Junior Subordinated Note             500000000        500000000
# 1               Senior Note            1000000000       1000000000

# %% [markdown]
# #### Example - Top executives

# %%
# Using the People View, we can utilize the OfficerDirector property, which contains a number of nested or sub-properties 
# that allow me to perform a more fine-grained search against active people that have been assigned a title code of 
# CEO (Chief Executive Officer). The results are listed based on a default rank defined by the search service.
response=search.Definition(
    view = search.SearchViews.PEOPLE,
    filter = "OfficerDirector(RoleTitleCode eq 'CEO' and RoleStatus eq 'Active')",
    top = 20,
    select = "FullName, PrimaryTitleAsReported, PrimaryOfficerDirector, RIC, OfficerDirectorActiveCompanies, PrimaryOfficerDirectorRIC"
).get_data()
response.data.df
# Out:
#                  FullName  \
# 0           Satya Nadella
# 1             Tim D. Cook
# 2         Andrew R. Jassy
# 3           Sundar Pichai
# 4         Mark Zuckerberg
# 5       Warren E. Buffett
# 6            Daniel Zhang
# 7               Fan Jiang
# 8            Weijian Shan
# 9              Huateng Ma
# 10       Al Francis Kelly
# 11     Joaquin Boix Duato
# 12   A. Eugene Washington
# 13         Jamie L. Dimon
# 14        Daniel E. Pinto
# 15    Mark Mark Schneider
# 16         Laurent Freixe
# 17          Doug McMillon
# 18          Tom W. Horton
# 19  Randall L. Stephenson
#
#                                                                          PrimaryTitleAsReported  \
# 0                                                Chairman of the Board, Chief Executive Officer
# 1                                                             Chief Executive Officer, Director
# 2                                                  President, Chief Executive Officer, Director
# 3                                                             Chief Executive Officer, Director
# 4                                       Chairman of the Board, Chief Executive Officer, Founder
# 5                                                Chairman of the Board, Chief Executive Officer
# 6                                                Chairman of the Board, Chief Executive Officer
# 7                                                                  President - Taobao and Tmall
# 8                                                                          Independent Director
# 9                                      Executive Chairman of the Board, Chief Executive Officer
# 10                                               Chairman of the Board, Chief Executive Officer
# 11                                                            Chief Executive Officer, Director
# 12                                                                         Independent Director
# 13                                               Chairman of the Board, Chief Executive Officer
# 14                                                           President, Chief Operating Officer
# 15                   Chief Executive Officer, Executive Director, Member of the Executive Board
# 16  Member of the Executive Board, Executive Vice President, Chief Executive Officer Zone LATAM
# 17                                                 President, Chief Executive Officer, Director
# 18                                                                    Lead Independent Director
# 19                                                                         Independent Director
#
#        PrimaryOfficerDirector  \
# 0              Microsoft Corp
# 1                   Apple Inc
# 2              Amazon.com Inc
# 3                Alphabet Inc
# 4          Meta Platforms Inc
# 5      Berkshire Hathaway Inc
# 6   Alibaba Group Holding Ltd
# 7   Alibaba Group Holding Ltd
# 8   Alibaba Group Holding Ltd
# 9        Tencent Holdings Ltd
# 10                   Visa Inc
# 11          Johnson & Johnson
# 12          Johnson & Johnson
# 13        JPMorgan Chase & Co
# 14        JPMorgan Chase & Co
# 15                  Nestle SA
# 16                  Nestle SA
# 17                Walmart Inc
# 18                Walmart Inc
# 19                Walmart Inc
#
#                                                                                                                  OfficerDirectorActiveCompanies  \
# 0                                                  [Starbucks Corp, Microsoft Deutschland GmbH, Chandler Insurance Company Ltd, Microsoft Corp]
# 1                                                                                                    [Apple Inc, Nike Inc, Apple Retail Uk Ltd]
# 2                                                                                                          [Coupa Software Inc, Amazon.com Inc]
# 3                                                                                                    [Alphabet Inc, Ruba  Inc (Fka  Kudo  Inc)]
# 4                                                                                          [Chan Zuckerberg Initiative LLC, Meta Platforms Inc]
# 5   [Grinnell College, Bill & Melinda Gates Foundation Trust, Berkshire Hathaway Inc, Kraft Heinz Intermediate Corporation II, Kraft Heinz F...
# 6                                                                                                  [Alibaba Group Holding Ltd, DiDi Global Inc]
# 7                                                                                             [Alibaba Group Holding Ltd, Umeng Technology Ltd]
# 8   [Wilmar Ventures Pte Ltd, Alibaba Group Holding Ltd, TCC International Holdings Ltd, Pacific Alliance Group Ltd, Storybook Entertainment...
# 9                                                                                     [Tencent Holdings Ltd, Tencent Technology Beijing Co Ltd]
# 10                                                                                                                                   [Visa Inc]
# 11                                                                                                                          [Johnson & Johnson]
# 12                                                       [Duke University Health System Inc, Johnson & Johnson, Robert Wood Johnson Foundation]
# 13  [Deccan Hospital Corpn Ltd, Clearing House Payments Company LLC, JP Morgan Partners LLC, JPMorgan Chase & Co, Travelers Property Casualt...
# 14                                 [Chrysalead, JP Morgan Investment Management Inc, Stanhope Capital LLP, JPMorgan Chase & Co, S4 Capital PLC]
# 15                                                                                                                                  [Nestle SA]
# 16                                                                        [Nestle SA, Nestle Holdings Inc, Nestle Argentina SA, Nestle Peru SA]
# 17                                                                                                                                [Walmart Inc]
# 18                                   [General Electric Co, Walmart Inc, Grange National Banc Corp, American Airlines Inc, EnLink Midstream LLC]
# 19                                                                         [New Cingular Wireless Services Inc, Walmart Inc, AT&T Mobility LLC]
#
#    PrimaryOfficerDirectorRIC
# 0                     MSFT.O
# 1                     AAPL.O
# 2                     AMZN.O
# 3                    GOOGL.O
# 4                       FB.O
# 5                       BRKa
# 6                     BABA.K
# 7                     BABA.K
# 8                     BABA.K
# 9                    0700.HK
# 10                         V
# 11                       JNJ
# 12                       JNJ
# 13                       JPM
# 14                       JPM
# 15                    NESN.S
# 16                    NESN.S
# 17                       WMT
# 18                       WMT
# 19                       WMT
