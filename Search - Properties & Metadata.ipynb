# %% [markdown]
# ## Properties / Metadata
# The document properties represent the fields that define the data elements you want to retrieve as well as the elements you choose to filter your results.  In addition, properties are at the heart of other Search parameters such as Navigation, Grouping, and Boosting.  There are hundreds of properties available for each View providing critical details needed to fulfill your searching requirements.
#
# In order for you to be successful at search, you will need to understand how to access the available properties, how to determine what values they contain and what they mean.
#
# **Note**: The concepts outlined within this notebook provide the mechanism to manually extract properties and values.  While the techniques outlined are a great tool in understanding
#       how to better understand these attributes, the tasks to extract these details can be cumbersome.  As a way to significantly reduce this effort, I've
#       created a [convenient package](https://github.com/Refinitiv-API-Samples/Article.RDPLibrary.Python.SearchBrowser) that will allow users to discover properties and values much easier when searching.  This utility piggybacks off of the techniques outlined here.

# %%
import refinitiv.data as rd
from refinitiv.data.content import search
import pandas as pd

# Default session - desktop
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x7f1a44b27760 {name='codebook'}>

# %%
# Uncomment the following to see a larger data set when displaying to the screen.
pd.set_option('display.max_colwidth', 140)
#pd.set_option('display.max_rows', 10000)

rd.__version__
# Out:
# '1.0.0b10'

# %%
help(search.SearchViews)
# Out:
# Help on class SearchViews in module refinitiv.data._data.content.search.search_view_type:
#
# class SearchViews(enum.Enum)
#  |  SearchViews(value, names=None, *, module=None, qualname=None, type=None, start=1)
#  |
#  |  Possible views values to request data from 'search' endpoint
#  |
#  |  Method resolution order:
#  |      SearchViews
#  |      enum.Enum
#  |      builtins.object
#  |
#  |  Data and other attributes defined here:
#  |
#  |  BOND_FUT_OPT_QUOTES = <SearchViews.BOND_FUT_OPT_QUOTES: 'BondFutOptQuo...
#  |
#  |  CDS_INSTRUMENTS = <SearchViews.CDS_INSTRUMENTS: 'CdsInstruments'>
#  |
#  |  CDS_QUOTES = <SearchViews.CDS_QUOTES: 'CdsQuotes'>
#  |
#  |  CMO_INSTRUMENTS = <SearchViews.CMO_INSTRUMENTS: 'CmoInstruments'>
#  |
#  |  CMO_QUOTES = <SearchViews.CMO_QUOTES: 'CmoQuotes'>
#  |
#  |  COMMODITY_QUOTES = <SearchViews.COMMODITY_QUOTES: 'CommodityQuotes'>
#  |
#  |  DEALS_MERGERS_AND_ACQUISITIONS = <SearchViews.DEALS_MERGERS_AND_ACQUIS...
#  |
#  |  DERIVATIVE_INSTRUMENTS = <SearchViews.DERIVATIVE_INSTRUMENTS: 'Derivat...
#  |
#  |  DERIVATIVE_QUOTES = <SearchViews.DERIVATIVE_QUOTES: 'DerivativeQuotes'...
#  |
#  |  EQUITY_DERIVATIVE_INSTRUMENTS = <SearchViews.EQUITY_DERIVATIVE_INSTRUM...
#  |
#  |  EQUITY_DERIVATIVE_QUOTES = <SearchViews.EQUITY_DERIVATIVE_QUOTES: 'Equ...
#  |
#  |  EQUITY_INSTRUMENTS = <SearchViews.EQUITY_INSTRUMENTS: 'EquityInstrumen...
#  |
#  |  EQUITY_QUOTES = <SearchViews.EQUITY_QUOTES: 'EquityQuotes'>
#  |
#  |  FIXED_INCOME_INSTRUMENTS = <SearchViews.FIXED_INCOME_INSTRUMENTS: 'Fix...
#  |
#  |  FIXED_INCOME_QUOTES = <SearchViews.FIXED_INCOME_QUOTES: 'FixedIncomeQu...
#  |
#  |  FUND_QUOTES = <SearchViews.FUND_QUOTES: 'FundQuotes'>
#  |
#  |  GOV_CORP_INSTRUMENTS = <SearchViews.GOV_CORP_INSTRUMENTS: 'GovCorpInst...
#  |
#  |  GOV_CORP_QUOTES = <SearchViews.GOV_CORP_QUOTES: 'GovCorpQuotes'>
#  |
#  |  INDEX_INSTRUMENTS = <SearchViews.INDEX_INSTRUMENTS: 'IndexInstruments'...
#  |
#  |  INDEX_QUOTES = <SearchViews.INDEX_QUOTES: 'IndexQuotes'>
#  |
#  |  INDICATOR_QUOTES = <SearchViews.INDICATOR_QUOTES: 'IndicatorQuotes'>
#  |
#  |  INSTRUMENTS = <SearchViews.INSTRUMENTS: 'Instruments'>
#  |
#  |  IRD_QUOTES = <SearchViews.IRD_QUOTES: 'IRDQuotes'>
#  |
#  |  LOAN_INSTRUMENTS = <SearchViews.LOAN_INSTRUMENTS: 'LoanInstruments'>
#  |
#  |  LOAN_QUOTES = <SearchViews.LOAN_QUOTES: 'LoanQuotes'>
#  |
#  |  MONEY_QUOTES = <SearchViews.MONEY_QUOTES: 'MoneyQuotes'>
#  |
#  |  MORTGAGE_INSTRUMENTS = <SearchViews.MORTGAGE_INSTRUMENTS: 'MortgageIns...
#  |
#  |  MORT_QUOTES = <SearchViews.MORT_QUOTES: 'MortQuotes'>
#  |
#  |  MUNICIPAL_INSTRUMENTS = <SearchViews.MUNICIPAL_INSTRUMENTS: 'Municipal...
#  |
#  |  MUNICIPAL_QUOTES = <SearchViews.MUNICIPAL_QUOTES: 'MunicipalQuotes'>
#  |
#  |  ORGANISATIONS = <SearchViews.ORGANISATIONS: 'Organisations'>
#  |
#  |  PEOPLE = <SearchViews.PEOPLE: 'People'>
#  |
#  |  PHYSICAL_ASSETS = <SearchViews.PHYSICAL_ASSETS: 'PhysicalAssets'>
#  |
#  |  QUOTES = <SearchViews.QUOTES: 'Quotes'>
#  |
#  |  QUOTES_AND_STIRS = <SearchViews.QUOTES_AND_STIRS: 'QuotesAndSTIRs'>
#  |
#  |  SEARCH_ALL = <SearchViews.SEARCH_ALL: 'SearchAll'>
#  |
#  |  STIRS = <SearchViews.STIRS: 'STIRs'>
#  |
#  |  VESSEL_PHYSICAL_ASSETS = <SearchViews.VESSEL_PHYSICAL_ASSETS: 'VesselP...
#  |
#  |  YIELD_CURVE_CONT_QUOTES = <SearchViews.YIELD_CURVE_CONT_QUOTES: 'Yield...
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from enum.Enum:
#  |
#  |  name
#  |      The name of the Enum member.
#  |
#  |  value
#  |      The value of the Enum member.
#  |
#  |  ----------------------------------------------------------------------
#  |  Readonly properties inherited from enum.EnumMeta:
#  |
#  |  __members__
#  |      Returns a mapping of member name->value.
#  |
#  |      This mapping lists all enum members, including aliases. Note that this
#  |      is a read-only view of the internal mapping.

# %% [markdown]
# #### Metadata
# MetaData is a convenient service that allows you to list all available properties within a View.  To properly build a metadata list for inspection, you can issue the following:

# %%
# Specify the view
response = search.metadata.Definition(
    view = search.SearchViews.COMMODITY_QUOTES
).get_data()
response.data.df
# Out:
#                                  Type  Searchable  Sortable  Navigable  \
# AAACurrencyBondBenchmarkChain  String       False     False      False
# AACurrencyBondBenchmarkChain   String       False     False      False
# ABSMBSBondsRIC                 String       False     False      False
# ActivityDate                     Date        True      True       True
# ACurrencyBondBenchmarkChain    String       False     False      False
# ...                               ...         ...       ...        ...
# WarrantsCount                  Double        True      True       True
# WarrantType                    String        True     False      False
# WarrantTypeName                String        True     False      False
# Wert                           String        True     False      False
# XMSAssetCategory               String        True     False      False
#
#                                Groupable  Exact  Symbol
# AAACurrencyBondBenchmarkChain      False  False   False
# AACurrencyBondBenchmarkChain       False  False   False
# ABSMBSBondsRIC                     False  False   False
# ActivityDate                       False  False   False
# ACurrencyBondBenchmarkChain        False  False   False
# ...                                  ...    ...     ...
# WarrantsCount                      False  False   False
# WarrantType                        False  False   False
# WarrantTypeName                    False  False   False
# Wert                                True  False    True
# XMSAssetCategory                   False  False   False
#
# [612 rows x 7 columns]

# %%
# Export metadata to a spreadsheet for easy viewing
response.data.df.to_excel("CommodityQuotes.xlsx")

# %% [markdown]
# ## Common and Special Properties

# %% [markdown]
# #### Debugging (*_debugall*)
# While MetaData will help list all properties available within a View, all properties will not be available for use.  That is, depending on the type of search you perform, will determine which properties will be populated - not all will be.  This is where users can use a technique to list all available properties that are populated, for the specific search requested.

# %%
# Query for all documents with the company IBM defined
response=search.Definition(
    query = "IBM",
    top = 1,    # Note: It is critical you select a top=1 because the amount of data returned is very large.
    select = "_debugall"
).get_data()
response.data.raw
# Out:
# {'Total': 45304,
#  'Hits': [{'meta': {'_id': '37036',
#     '_index': 'eikonsearch_organisation_1.139.0',
#     '_score': 2838909,
#     '_timestamp': 1650644095021,
#     '_timestamp_human': '2022-04-22T16:14:55.021Z',
#     '_version': 1650641738000},
#    'raw_source': {'RCSOrganisationTypeGenealogy': 'OT:1',
#     'SPsRatingOutlookX1XSPsRatingOutlookRank': 'SPI/StableX1X0|SPI/StableX1X0',
#     'RCSTRBCGenealogy': 'B:161\\B:171\\B:172\\B:173',
#     'IssuerID': '0x000019000050e3aa',
#     'SicSchemeCode': '8742',
#     'OfficersExist': True,
#     'IssuerBondsExist': True,
#     'CertificatesOfDepositCount': 0,
#     'MktCapCompanyUsd': 125768501542,
#     'TotalAssetsUsd': 132001000000,
#     'GEMPermID': '4295904307',
#     'SubjectBoost': 'firm',
#     'EEDBID': '14129',
#     'SigDevExist': True,
#     'SDCID': '3104001',
#     'TotalAssets': 132001000000,
#     'EstimatesExist': True,
#     'Ticker': 'IBM',
#     'CdsUltimateParentCount': 0,
#     'FilingsExist': True,
#     'CompanyOfficers': 'Senior Vice President:Erich Clementi |Senior Vice President:Diane J. Gherson |Senior Vice President:Martin J. Schroeter |Senior Vice President:John E. Kelly |Senior Vice President:Michelle H. Browdy |Chief Financial Officer:James J. Kavanaugh |Senior Vice President:Kenneth M. Keverian |Vice President:Robert F. Del Bene |Chairman:Virginia M. Rometty',
#     'CompositeSearchAllZh': '公司',
#     'CommonNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'RatingOutlookRank': 'MDL/0|MRS/0|MDL/0',
#     'CurrentRatio': 0.87864,
#     'UltimateParentOrganisationOrgid': '18228',
#     'PreviousNames': 'COMPUTING-TABULATING-RECORDING-CO.|1911-06-16|1924-02-14',
#     'TRBCHierarchicalCode': '5720101010',
#     'NetProfit': 5743000000,
#     'PrimaryIssuePILC': '144477',
#     'IsExchange': False,
#     'RCSOriginalAccountsCurrencyLeafML': 'ja 米ドル|zh-Hans 美元|zh-Hant 美元',
#     'DTSubjectNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'RCSOriginalAccountsCurrencyLeaf': 'US Dollar',
#     'SPsRatingScopeRank': 'SPI/2|SSU/2|SIS/2|SIS/1|SCP/1|SCP/2|SSU/1|SPI/1|SMU/2|SMU/1',
#     'CompositeSearchAllJa': '事業法人',
#     'IsMainCompanyFiling': True,
#     'RatingsScope': [{'Agency': 'FTC',
#       'RatingType': 'FDL',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJC',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2018-11-02T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MIS',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MIS',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJC',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2019-01-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MDL',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'D',
#       'Outlook': 'Stable'},
#      {'Agency': 'FTC',
#       'RatingType': 'FCP',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2007-05-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2018-10-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2015-07-15T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FDT',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2018-10-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2016-11-18T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MCP',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FSU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MCP',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MRS',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'F',
#       'Outlook': 'Stable'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJU',
#       'CurrentRatingRank': 8,
#       'CurrentRatingDate': '2020-04-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MSU',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'EGJ',
#       'RatingType': 'EJU',
#       'CurrentRatingRank': 8,
#       'CurrentRatingDate': '2020-04-29T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FDS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2019-07-01T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'FTC',
#       'RatingType': 'FIS',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2005-10-05T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'F'},
#      {'Agency': 'MDY',
#       'RatingType': 'MMU',
#       'CurrentRatingRank': 98,
#       'CurrentRatingDate': '2016-11-18T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'RatingScope': 'D'},
#      {'Agency': 'FTC',
#       'RatingType': 'FCP',
#       'CurrentRatingRank': 2,
#       'CurrentRatingDate': '2007-05-30T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'MDY',
#       'RatingType': 'MDL',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-10-14T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'n',
#       'OutlookRank': 0,
#       'RatingScope': 'F',
#       'Outlook': 'Stable'}],
#     'RatingType': 'Issuer/FTC/FDL|Issuer/EGJ/EJC|Issuer/MDY/MIS|Issuer/MDY/MSU|Issuer/MDY/MIS|Issuer/EGJ/EJC|Issuer/MDY/MDL|Issuer/FTC/FCP|Issuer/FTC/FSS|Issuer/FTC/FSU|Issuer/FTC/FMU|Issuer/FTC/FDT|Issuer/MDY/MMU|Issuer/MDY/MCP|Issuer/FTC/FSU|Issuer/MDY/MCP|Issuer/MDY/MRS|Issuer/EGJ/EJU|Issuer/MDY/MSU|Issuer/EGJ/EJU|Issuer/FTC/FDS|Issuer/FTC/FIS|Issuer/MDY/MMU|Issuer/FTC/FCP|Issuer/MDY/MDL',
#     'SPsRatingNameX1XSPsRatingType': "Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Issuer RatingX1XSPI|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Senior UnsecuredX1XSSU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Short-term Issuer Credit RatingX1XSIS|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Short-term Issuer Credit RatingX1XSIS|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Commercial PaperX1XSCP|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Commercial PaperX1XSCP|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Senior UnsecuredX1XSSU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Issuer RatingX1XSPI|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Senior Unsecured MTN RatingX1XSMU|Issuer/Standard & Poor's Bond Rating ServicesX1XS&P/S&P Long-term Senior Unsecured MTN RatingX1XSMU",
#     'AddressLine1': '1 New Orchard Rd',
#     'RCSCountryHeadquarters': 'G:6J',
#     'ParentCompanyNDAPI': '37036',
#     'GicsName': 'Information Technology|Information Technology/Software & Services|Information Technology/Software & Services/IT Services|Information Technology/Software & Services/IT Services/IT Consulting & Other Services',
#     'InvestmentCertificateCount': 0,
#     'SuggestPhrase': 'internatnl intl intrnl | it services & consulting (nec) organisation corporation listed |big blue|guo ji shang ye ji qi gong si|guo ji shang yong ji qi|ibm|intanashonaru bijinesu mashinzu|international business machines|international business machines corp|software artistry inc|unison software inc|international business machines corp|international business machines corporation|never',
#     'OAOrgSubTypeName': 'Operating Company',
#     'ListingStatusName': 'Listed',
#     'RCSCountryHeadquartersLeafML': 'ja 米国|zh-Hans 美国|zh-Hant 美國|es Estados Unidos|fr États Unis|ko 미국|ru США',
#     'RCSTRBCName': 'Technology\\Software & IT Services\\Software & IT Services\\IT Services & Consulting',
#     'RCSOrganisationTypeNameML': 'ja 事業法人|zh-Hans 公司|zh-Hant 公司',
#     'LongTermDebt': 54355000000,
#     'RCSTRBC2012NameML': 'ja テクノロジー\\ソフトウェア & IT サービス\\ソフトウェア & IT サービス\\IT サービス & コンサルティング\\IT サービス & コンサルティング (その他)|zh-Hans 技术\\软件及信息技术服务\\软件及信息技术服务\\信息技术服务及咨询\\IT 服务及咨询 (其他 (NEC))|zh-Hant 技術\\軟體及信息技術服務\\軟體及信息技術服務\\信息技術服務及諮詢\\IT 服務及諮詢 (其他 (NEC))',
#     'SPsRatingX1XSPsRatingScopeRank': 'SPI/FX1X2|SSU/FX1X2|SIS/FX1X2|SIS/DX1X1|SCP/DX1X1|SCP/FX1X2|SSU/DX1X1|SPI/DX1X1|SMU/FX1X2|SMU/DX1X1',
#     'Ev': 179943501542,
#     'PrimaryRICRCSAssetCategory': 'A:1L',
#     'RCSFilingCurrencyName': 'US Dollar',
#     'UltimateParentOrganisationName': 'International Business Machines Corp',
#     'BusinessDescription': 'International Business Machines Corporation (IBM) is a technology company. The Company segments include Cloud & Cognitive Software, Global Business Services (GBS), Systems and Global Financing. The Cloud & Cognitive Software Solutions segment delivers integrated and secure cloud, data and artificial intelligence (AI) solutions to its clients. It comprises three business areas: cognitive applications, cloud & data platforms, and transaction processing platforms. The GBS segment provides consulting, business process and application management services. The Global Financing segment is engaged in financing, which is primarily conducted through IBM Credit LLC, and remanufacturing and remarketing. The Systems segment provides clients with infrastructure platforms to help meet the requirements of hybrid multi-cloud and enterprise AI workloads. It also provides telco consulting services and solutions to help communications service providers (CSP) and media on multiple cloud platforms.',
#     'RCSCountryOfIncorporationGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'TRBCPrimaryCode': '173',
#     'CommonNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RatingScopeRank': 'FDL/2|EJC/1|MIS/1|MSU/2|MIS/2|EJC/2|MDL/1|FCP/2|FSS/2|FSU/2|FMU/1|FDT/1|MMU/2|MCP/1|FSU/1|MCP/2|MRS/2|EJU/2|MSU/1|EJU/1|FDS/2|FIS/2|MMU/1|FCP/1|MDL/2',
#     'LegalNameJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション',
#     'OpMargin': 8.959024,
#     'SearchAllCategory': 'Companies/Issuers',
#     'RCSOriginalAccountsCurrency': 'C:6',
#     'RCSTRBC2012': 'B:1790',
#     'SicScheme': 'Engineering and management services/Management and Public Relations/Management Consulting Services',
#     'SearchTypeBase': 1,
#     'RatingX1XRatingScopeRank': 'FDL/FX1X2|EJC/DX1X1|MIS/DX1X1|MSU/FX1X2|MIS/FX1X2|EJC/FX1X2|MDL/DX1X1|FCP/FX1X2|FSS/FX1X2|FSU/FX1X2|FMU/DX1X1|FDT/DX1X1|MMU/FX1X2|MCP/DX1X1|FSU/DX1X1|MCP/FX1X2|MRS/FX1X2|EJU/FX1X2|MSU/DX1X1|EJU/DX1X1|FDS/FX1X2|FIS/FX1X2|MMU/DX1X1|FCP/DX1X1|MDL/FX1X2',
#     'InterestCover': 4.448485,
#     'CommonName': 'International Business Machines Corp',
#     'OAOrgTypeName': 'Business Organization',
#     'NAVPrimaryRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBM"/><a:Req value="62" scheme="IDN"/><a:Req value="6216" scheme="IDN"/></a:Entity></a:Rship>',
#     'MainFilingType': 'CONSOLIDATED',
#     'OrganizationWebsite': 'https://www.ibm.com/',
#     'EquityInstrumentsCount': 4,
#     'UltimateParentCompanyOAPermID': '4295904307',
#     'SPsRatingPreliminary': 'SPI/n|SSU/n|SIS/n|SIS/n|SCP/n|SCP/n|SSU/n|SPI/n|SMU/n|SMU/n',
#     'PrimaryRICCUSIP': '459200101',
#     'DTSubjectNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RCSFilingCountryLeaf': 'United States',
#     'MainFilingCommonName': 'International Business Machines Corp.',
#     'DocumentsExist': True,
#     'RCSTRBCLeaf': 'IT Services & Consulting',
#     'ShortTermDebt': 7183000000,
#     'TRBC2012PrimaryCode': '1790',
#     'ParentCompanyOAPermID': '4295904307',
#     'AddressCity': 'ARMONK',
#     'IndicesCount': 0,
#     'RbssSchemeCode': '1790',
#     'Filename': 'Update_CL3_AWSPRODA_A1.1_Organisation_0474490_20220422_153538_A_incr_wi_015944.xml.xz',
#     'PretaxProfitUsd': 4837000000,
#     'MainRepnoAttributes': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="ActiveEstimatesExist" value="Y"/><a:Prop name="BusinessIntelligenceExists" value="Y"/><a:Prop name="FundamentalsExist" value="Y"/><a:Prop name="EstimatesExist" value="Y"/><a:Prop name="SigDevExist" value="Y"/><a:Prop name="OfficersExist" value="Y"/><a:Prop name="Repno" value="4741N"/><a:Prop name="CommonName" value="International Business Machines Corp."/><a:Prop name="Type" value="CONSOLIDATED"/><a:Prop name="IsMainIssueFiling" value="Y"/><a:Prop name="IsMainCompanyFiling" value="Y"/><a:Prop name="RCSCurrencyName" value="US Dollar"/><a:Prop name="RCSCountryLeaf" value="United States"/></a:Entity></a:Rship>',
#     'RevenueUsd': 57350000000,
#     'IsPublic': True,
#     'OwnershipExists': True,
#     'OAPermID': '4295904307',
#     'Ebit': 5138000000,
#     'DebtToEquity': 5.978784,
#     'CompanyDataStreamID': '003671',
#     'IsTRACEEligible': True,
#     'InsertDateTime': '2022-01-07T18:27:04.000Z',
#     'SynonymDescriptiveName': 'internatnl INTL intrnl',
#     'CDS5YSuperRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="RIC" value="IBM5YUSAX="/><a:Prop name="DisplayName" value="IBM" lang="en"/><a:Req value="6995" scheme="IDN"/></a:Entity></a:Rship>',
#     'RCSFilingCountryNameML': 'ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\北大西洋公约组织\\美国|zh-Hant 國家分組\\北大西洋公約組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|es Continentes/regiones\\Continente Americano\\Norteamérica\\Estados Unidos|fr Continents/Régions\\Amérique\\Amérique du Nord\\États Unis|ja 大陸 / 地域\\北米 & 中南米\\北米\\米国|ru Континенты/регионы\\Америка\\Северная Америка\\США|zh-Hans 大陆/地区\\美洲\\北美\\美国|zh-Hant 大陸/地區\\美洲\\北美\\美國|ko \\미주\\북아메리카\\미국|ja 国際機関\\\\米国|zh-Hans 国家分组\\亚太经济合作组织\\美国|zh-Hant 國家分組\\亞太經濟合作組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\经济合作与发展组织\\美国|zh-Hant 國家分組\\經濟合作與發展組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国\\米国|zh-Hans 国家/地区\\美国|zh-Hant 國家/地區\\美國|es \\Estados Unidos|fr \\États Unis|ko \\미국|ru \\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja FRUC 地域\\グローバル\\北米\\米国|zh-Hans FRUC 区域\\全球\\北美\\美国|zh-Hant FRUC 區域\\全球\\北美\\美國|es \\\\\\Estados Unidos|fr \\\\\\États Unis|ko \\\\\\미국|ru \\\\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\G10 集团\\美国|zh-Hant 國家分組\\G10 集團\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\北米\\米国|zh-Hans 国家分组\\北美\\美国|zh-Hant 國家分組\\北美\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США',
#     'MnaParentTargetCount': 0,
#     'SectorIndices': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="DisplayName" value="DOW JONES TECHNOLOGY NDX" lang="en"/><a:Prop name="RIC" value=".DJUSTC"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="2"><a:Prop name="DisplayName" value="S&amp;P 500 IT Consulting&amp;Other Serv(SI)" lang="en"/><a:Prop name="RIC" value=".SPLRCTKCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="3"><a:Prop name="DisplayName" value="S&amp;P 500 IT Services (Industry)" lang="en"/><a:Prop name="RIC" value=".SPLRCITCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="4"><a:Prop name="DisplayName" value="S&amp;P 500 Software &amp; Services (IG)" lang="en"/><a:Prop name="RIC" value=".SPLRCIS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="5"><a:Prop name="DisplayName" value="标普信息技术指数" lang="zh-Hans"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="6"><a:Prop name="DisplayName" value="S&amp;P 500種 情報技術セクター指数" lang="ja-Hani"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="7"><a:Prop name="DisplayName" value="S&amp;P 500 Information Tech(Sector)" lang="en"/><a:Prop name="RIC" value=".SPLRCT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="8"><a:Prop name="DisplayName" value="S&amp;P Composite 1500 Software&amp;Serv(IG)" lang="en"/><a:Prop name="RIC" value=".SPCOMIS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="9"><a:Prop name="DisplayName" value="S&amp;P 1500 IT Services (Ind)" lang="en"/><a:Prop name="RIC" value=".SPCOMITCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="10"><a:Prop name="DisplayName" value="S&amp;P 1500 Info Technology (Sector)" lang="en"/><a:Prop name="RIC" value=".SPCOMT"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="11"><a:Prop name="DisplayName" value="S&amp;P 1500 ITConsulting&amp;Other Serv(SI)" lang="en"/><a:Prop name="RIC" value=".SPCOMTKCS"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="12"><a:Prop name="DisplayName" value="ARCA COMPUT TECH" lang="en"/><a:Prop name="RIC" value=".XCI"/><a:Req value="6465" scheme="IDN"/><a:Req value="5053" scheme="IDN"/></a:Entity><a:Entity rank="13"><a:Prop name="DisplayName" value="Refinitiv United States Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDUSPTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="14"><a:Prop name="DisplayName" value="Refinitiv North America Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNAPUTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="15"><a:Prop name="DisplayName" value="Refinitiv NAFTA Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNFPUTEC"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="16"><a:Prop name="DisplayName" value="Refinitiv G7 Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDG7PUTEC"/><a:Req value="3112" scheme="IDN"/></a:Entity><a:Entity rank="17"><a:Prop name="DisplayName" value="Refinitiv Global Technology Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDGLPUTEC"/><a:Req value="3112" scheme="IDN"/></a:Entity></a:Rship>',
#     'OpProfitInterim': 134000000,
#     'Source': 'NDA',
#     'DisclosureIDs': 'I510600000',
#     'RCSFilingCountry': 'G:6J',
#     'GeneralAliasNameZhHans': '国际商业机器公司|国际商用机器',
#     'RCSTRBCNameML': 'ja テクノロジー\\ソフトウェア & IT サービス\\ソフトウェア & IT サービス\\IT サービス & コンサルティング|zh-Hans 技术\\软件及信息技术服务\\软件及信息技术服务\\信息技术服务及咨询|zh-Hant 技術\\軟體及信息技術服務\\軟體及信息技術服務\\信息技術服務及諮詢',
#     'SPsRatingX1XSPsRatingRankForeign': 'SPI/A-X1X7|SSU/A-X1X13|SIS/A-2X1X3|SCP/A-2X1X3|SMU/NRX1X0',
#     'CalaisAlias': "International Business Machines Corporation|IBM Corporation|INTL Business Machines Corp|International Business machines|IBM Corp.|International Business Machines|International Business Machines (IBM)|Intl Business Machines Corp|International Business Machines Corp|INTL|International Business|Software, Inc.|Business Machines Corp|International Business Machines Corp.|Unison|IBM Corp|INTERNATIONAL BUSINESS MACHINES CORP|International Business Machines Corporation (IBM)|@IBM|IBM's|IBM|International|INTERNATIONAL BUSINESS MACHINES|IBM Inc|International Business Machines Corp's (IBM|INTERNATIONAL BUSINESS MACHINES CORPORATION|International Business Machines Corp (IBM)|International Business Machines Corp .|International Business Machines Corp  .|IBM CORP|Big Ag",
#     'GeneralAliasName': 'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|International Business Machines Corp|Software Artistry Inc|Unison Software Inc',
#     'Gics': 'Information Technology/Software & Services/IT Services/IT Consulting & Other Services',
#     'SPsRatings': '<EntityList xmlns="uri://GenericEntityContainer_2.xsd"><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Issuer Rating"/><Property name="RatingTypeCode" value="SPI"/><Property name="CurrentRating" value="A-"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="Outlook" value="Stable"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Senior Unsecured"/><Property name="RatingTypeCode" value="SSU"/><Property name="CurrentRating" value="A-"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Short-term Issuer Credit Rating"/><Property name="RatingTypeCode" value="SIS"/><Property name="CurrentRating" value="A-2"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Short-term Issuer Credit Rating"/><Property name="RatingTypeCode" value="SIS"/><Property name="CurrentRating" value="A-2"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Commercial Paper"/><Property name="RatingTypeCode" value="SCP"/><Property name="CurrentRating" value="A-2"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Commercial Paper"/><Property name="RatingTypeCode" value="SCP"/><Property name="CurrentRating" value="A-2"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Senior Unsecured"/><Property name="RatingTypeCode" value="SSU"/><Property name="CurrentRating" value="A-"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Issuer Rating"/><Property name="RatingTypeCode" value="SPI"/><Property name="CurrentRating" value="A-"/><Property name="CurrentRatingDate" value="2021-05-06"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="y"/><Property name="Outlook" value="Stable"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Standard &amp; Poor&apos;s Bond Rating Services"/><Property name="RatingType" value="S&amp;P Long-term Senior Unsecured MTN Rating"/><Property name="RatingTypeCode" value="SMU"/><Property name="CurrentRating" value="NR"/><Property name="CurrentRatingDate" value=" ...
#     'LiquidityRIC': '0#IBM=',
#     'DocumentTitleJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん, Public Company',
#     'RCSTRBC2012Name': 'Technology\\Software & IT Services\\Software & IT Services\\IT Services & Consulting\\IT Services & Consulting (NEC)',
#     'MnaTargetCount': 0,
#     'TotalLiabilities': 113005000000,
#     'CompositeSymbolOnly': '18228',
#     'GeneralAliasNameZhHant': '國際商業機器公司',
#     'RCSPartyCountry': 'G:6J',
#     'IsLegacySearchContent': True,
#     'RbssScheme': 'IT Services & Consulting - NEC',
#     'PreferenceSharesCount': 9,
#     'RCSFilingCountryName': 'Country Grouping\\G7\\United States|Country Grouping\\NATO\\United States|Continent / Region\\Americas\\North America\\United States|Country Grouping\\APEC\\United States|Country Grouping\\OECD\\United States|Country Grouping\\G8\\United States|Country\\United States|Country Grouping\\G20\\United States|FRUC Regions\\Global\\North America\\United States|Country Grouping\\G10\\United States|Country Grouping\\North America\\United States',
#     'IssuersTRCDSCurveRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="RIC" value="0#IBMUSAXRBMK="/><a:Prop name="DisplayName" value="IBM" lang="en"/><a:Req value="7674" scheme="IDN"/></a:Entity></a:Rship>',
#     'PrimaryRIC': 'IBM',
#     'CommercialPaperCount': 0,
#     'RCSCountryHeadquartersName': 'Country Grouping\\G7\\United States|Country Grouping\\NATO\\United States|Continent / Region\\Americas\\North America\\United States|Country Grouping\\APEC\\United States|Country Grouping\\OECD\\United States|Country Grouping\\G8\\United States|Country\\United States|Country Grouping\\G20\\United States|FRUC Regions\\Global\\North America\\United States|Country Grouping\\G10\\United States|Country Grouping\\North America\\United States',
#     'SPsRatingRank': 'SPI/7|SSU/13|SIS/3|SIS/3|SCP/3|SCP/3|SSU/13|SPI/7|SMU/0|SMU/13',
#     'SynonymDescriptiveNameJa': 'インタナショナル コーポレイション',
#     'DTSubjectName': 'International Business Machines Corp',
#     'CostOfSales': -25865000000,
#     'RegistrationAuthorityName': 'New York State Department Of State',
#     'RevenueGrowth5Y': -6.421371,
#     'GicsCode': '45102010',
#     'CdsCount': 281,
#     'DebtToAssets': 0.856092,
#     'UltimateParentCompanyNDAPI': '37036',
#     'RatingPreliminary': 'FDL/n|EJC/n|MIS/n|MSU/n|MIS/n|EJC/n|MDL/n|FCP/n|FSS/n|FSU/n|FMU/n|FDT/n|MMU/n|MCP/n|FSU/n|MCP/n|MRS/n|EJU/n|MSU/n|EJU/n|FDS/n|FIS/n|MMU/n|FCP/n|MDL/n',
#     'TRBCHierarchicalShortCode': '572211',
#     'FundsCount': 0,
#     'OriginalAccountsCurrency': 'USD',
#     'FitchIssuerRating': 'WD',
#     'LegalNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'RCSOrganisationType': 'OT:1',
#     'CIK': '0000051143',
#     'RCSOrganisationSubType': 'OAOST:COR',
#     'Red6Code': '49EB20',
#     'PEBackedStatus': 'Never',
#     'RegistrationNumber': '30059',
#     'PrimaryRICPI': '1097326',
#     'RatingX1XRatingRankForeign': 'FDL/WDX1X98|MSU/A3X1X7|MIS/A3X1X7|EJC/A1X1X2|FCP/WDX1X98|FSS/WDX1X98|FSU/AX1X7|MMU/WRX1X98|MCP/P-2X1X2|MRS/P-2X1X2|EJU/BBB+X1X8|FDS/WDX1X98|FIS/WDX1X98|MDL/A3X1X7',
#     'RegistrationAuthorityOrganizationID': '5000064525',
#     'RatingX1XRatingRankDomestic': 'EJC/A1X1X2|MIS/A3X1X7|MDL/A3X1X7|FMU/WDX1X98|FDT/F1X1X2|MCP/P-2X1X2|FSU/WDX1X98|MSU/A3X1X7|EJU/BBB+X1X8|MMU/WRX1X98|FCP/F1X1X2',
#     'TotalOperatingIncome': 57350000000,
#     'SPsRatingOutlookRank': 'SPI/0|SPI/0',
#     'PrimaryRICRICUsageCount': 10464,
#     'RatingsExist': True,
#     'Orgid': '18228',
#     'NumberOfEmployees': 375300,
#     'SubsidiariesCount': 199,
#     'FundamentalsExist': True,
#     'IsActive': True,
#     'DTSubjectNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'InterimNetIncome': 733000000,
#     'OAOrgSubType': 'COR',
#     'SPIssuerRating': 'A-',
#     'BusinessEntity': 'ORGANISATION',
#     'DEBUGBATCH': 'Update_CL3_AWSPRODA_A1.1_Organisation_0474490_20220422_153538_A_incr_wi_015944.xml.xz',
#     'RCSTRBCLeafML': 'ja IT サービス & コンサルティング|zh-Hans 信息技术服务及咨询|zh-Hant 信息技術服務及諮詢',
#     'OrganisationTypeName': 'Corporation',
#     'CompositeIdentifyingCode': 'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM',
#     'Roe': 30.384636,
#     'OrganisationStatus': 'Listed',
#     'CurrentLiabilities': 39869000000,
#     'PrimaryRICTickerSymbol': 'IBM',
#     'RCSCountryHeadquartersNameML': 'ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\北大西洋公约组织\\美国|zh-Hant 國家分組\\北大西洋公約組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|es Continentes/regiones\\Continente Americano\\Norteamérica\\Estados Unidos|fr Continents/Régions\\Amérique\\Amérique du Nord\\États Unis|ja 大陸 / 地域\\北米 & 中南米\\北米\\米国|ru Континенты/регионы\\Америка\\Северная Америка\\США|zh-Hans 大陆/地区\\美洲\\北美\\美国|zh-Hant 大陸/地區\\美洲\\北美\\美國|ko \\미주\\북아메리카\\미국|ja 国際機関\\\\米国|zh-Hans 国家分组\\亚太经济合作组织\\美国|zh-Hant 國家分組\\亞太經濟合作組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\经济合作与发展组织\\美国|zh-Hant 國家分組\\經濟合作與發展組織\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国\\米国|zh-Hans 国家/地区\\美国|zh-Hant 國家/地區\\美國|es \\Estados Unidos|fr \\États Unis|ko \\미국|ru \\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\\\美国|zh-Hant 國家分組\\\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja FRUC 地域\\グローバル\\北米\\米国|zh-Hans FRUC 区域\\全球\\北美\\美国|zh-Hant FRUC 區域\\全球\\北美\\美國|es \\\\\\Estados Unidos|fr \\\\\\États Unis|ko \\\\\\미국|ru \\\\\\США|ja 国際機関\\\\米国|zh-Hans 国家分组\\G10 集团\\美国|zh-Hant 國家分組\\G10 集團\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США|ja 国際機関\\北米\\米国|zh-Hans 国家分组\\北美\\美国|zh-Hant 國家分組\\北美\\美國|es \\\\Estados Unidos|fr \\\\États Unis|ko \\\\미국|ru \\\\США',
#     'RCSTRBC2012LeafML': 'ja IT サービス & コンサルティング (その他)|zh-Hans IT 服务及咨询 (其他 (NEC))|zh-Hant IT 服務及諮詢 (其他 (NEC))',
#     'WarrantsCount': 4021,
#     'ParentOrganisationOrgid': '18228',
#     'DocumentTitle': 'International Business Machines Corp, Public Company',
#     'ShortName': 'IBM',
#     'DEBUGRANKRULES': '200001|300000',
#     'DTSimpleType': 'Public Company',
#     'UnderlyingEquityQuoteIssueCount': 0,
#     'Revenue': 57350000000,
#     'IsShariahCompliant': False,
#     'RCSTRBC2012Leaf': 'IT Services & Consulting (NEC)',
#     'IsPreIPO': False,
#     'PretaxProfitInterim': 623000000,
#     'ReutersIndustryClassification': 'Data Processing & Reproduction',
#     'OpProfit': 5138000000,
#     'RatingX1XRatingRank': 'FDL/WDX1X98|EJC/A1X1X2|MIS/A3X1X7|MSU/A3X1X7|MIS/A3X1X7|EJC/A1X1X2|MDL/A3X1X7|FCP/WDX1X98|FSS/WDX1X98|FSU/AX1X7|FMU/WDX1X98|FDT/F1X1X2|MMU/WRX1X98|MCP/P-2X1X2|FSU/WDX1X98|MCP/P-2X1X2|MRS/P-2X1X2|EJU/BBB+X1X8|MSU/A3X1X7|EJU/BBB+X1X8|FDS/WDX1X98|FIS/WDX1X98|MMU/WRX1X98|FCP/F1X1X2|MDL/A3X1X7',
#     'SuggestCompletion': [{'input': ['big',
#        'big blue',
#        'company',
#        'corporation',
#        'guo',
#        'guo ji',
#        'guo ji shang',
#        'guo ji shang ye',
#        'guo ji shang ye ji',
#        'guo ji shang ye ji qi',
#        'guo ji shang yong',
#        'guo ji shang yong ji',
#        'guo ji shang yong ji qi',
#        'ibm',
#        'intanashonaru',
#        'intanashonaru bijinesu',
#        'intanashonaru bijinesu mashinzu',
#        'international',
#        'international business',
#        'international business machines',
#        'international business machines corp',
#        'international business machines corporation',
#        'software',
#        'software artistry',
#        'software artistry inc',
#        'unison',
#        'unison software',
#        'unison software inc'],
#       'weight': 6453151},
#      {'input': ['company',
#        'corporation',
#        'ibm',
#        'it',
#        'it services',
#        'it services & consulting',
#        'it services & consulting (nec)'],
#       'weight': 1000000},
#      {'input': ['united', 'united states'], 'weight': 7000000}],
#     'CompositeSearchAll': 'IT Services & Consulting (NEC) ORGANISATION Corporation Listed',
#     'Rofa': 5.238338,
#     'NetProfitUsd': 5743000000,
#     'MortgagesCount': 0,
#     'AddressPostalCode': '10504-1722',
#     'IsMainIssueFiling': True,
#     'PrimaryRICISIN': 'US4592001014',
#     'RCSTRBC2012Genealogy': 'B:278\\B:171\\B:172\\B:290\\B:1790',
#     'Nd': 54031000000,
#     'PrimaryRICRICAcctsCount': 3490,
#     'LoanCount': 0,
#     'FtseScheme': 'Information Technology/Software & Computer Services/Computer Services',
#     'StaffCosts': -555000000,
#     'CPERMIDs': 'C000002474',
#     'IssuerCikNumber': '0000051143',
#     'CashAndEquivalents': 13212000000,
#     'RCSCountryHeadquartersLeaf': 'United States',
#     'CurrentAssets': 39165000000,
#     'PrimaryRICRCSAssetCategoryLeaf': 'Ordinary Share',
#     'RCSCountryOfIncorporation': 'G:6J',
#     'PrimaryRICExchangeCode': 'NYQ',
#     'TotalAssetsToEquity': 6.98381,
#     'SPsRatingX1XSPsRatingRankDomestic': 'SIS/A-2X1X3|SCP/A-2X1X3|SSU/A-X1X13|SPI/A-X1X7|SMU/A-X1X13',
#     'Ratings': '<EntityList xmlns="uri://GenericEntityContainer_2.xsd"><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Long-term Issuer Default Rating"/><Property name="RatingTypeCode" value="FDL"/><Property name="CurrentRating" value="WD"/><Property name="CurrentRatingDate" value="2019-07-01"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Egan-Jones Ratings Co."/><Property name="RatingType" value="Egan-Jones Commercial Paper"/><Property name="RatingTypeCode" value="EJC"/><Property name="CurrentRating" value="A1"/><Property name="CurrentRatingDate" value="2018-11-02"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MIS"/><Property name="CurrentRating" value="A3"/><Property name="CurrentRatingDate" value="2021-10-14"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Senior Unsecured"/><Property name="RatingTypeCode" value="MSU"/><Property name="CurrentRating" value="A3"/><Property name="CurrentRatingDate" value="2021-10-14"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MIS"/><Property name="CurrentRating" value="A3"/><Property name="CurrentRatingDate" value="2021-10-14"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Egan-Jones Ratings Co."/><Property name="RatingType" value="Egan-Jones Commercial Paper"/><Property name="RatingTypeCode" value="EJC"/><Property name="CurrentRating" value="A1"/><Property name="CurrentRatingDate" value="2019-01-30"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Moody&apos;s"/><Property name="RatingType" value="Moody&apos;s Derived Long-term Issuer Rating"/><Property name="RatingTypeCode" value="MDL"/><Property name="CurrentRating" value="A3"/><Property name="CurrentRatingDate" value="2021-10-14"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="Outlook" value="Stable"/><Property name="RatingScope" value="D"/></Entity><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Commercial Paper"/><Property name="RatingTypeCode" value="FCP"/><Property name="CurrentRating" value="WD"/><Property name="CurrentRatingDate" value="2019-07-01"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Short-term Issuer Rating"/><Property name="RatingTypeCode" value="FSS"/><Property name="CurrentRating" value="WD"/><Property name="CurrentRatingDate" value="2007-05-30"/><Property name="Preliminary" value="n"/><Property name="Solicited" value="n"/><Property name="RatingScope" value="F"/></Entity><Entity name="Rating"><Property name="Agency" value="Fitch"/><Property name="RatingType" value="Fitch Senior Unsecured"/><Property name="RatingTypeCode" value="FSU"/><Property name="CurrentRating" value="A"/><Property ...
#     'SDCCUSIP': '459200',
#     'Edcoid': 'IBM.N',
#     'LocalScheme': 'Industrial|Information Technology/Information Technology Hardware|Industrials/Computer Hardware',
#     'BusinessIntelligenceExists': True,
#     'QuickRatio': 0.82959,
#     'VEFirmID': '21142',
#     'CommonNameJaHira': 'いんたーなしょなるびじねすましーんずこーぽれーしょん',
#     'RCSTRBC': 'B:173',
#     'PI': '37036',
#     'Rota': 3.988582,
#     'VentureEconomicsID': '99636',
#     'PrimaryRICExchangeName': 'NYSE Consolidated',
#     'IsContributor': False,
#     'RatingRank': 'FDL/98|EJC/2|MIS/7|MSU/7|MIS/7|EJC/2|MDL/7|FCP/98|FSS/98|FSU/7|FMU/98|FDT/2|MMU/98|MCP/2|FSU/98|MCP/2|MRS/2|EJU/8|MSU/7|EJU/8|FDS/98|FIS/98|MMU/98|FCP/2|MDL/7',
#     'OpProfitUsd': 5138000000,
#     'RatingOutlookX1XRatingOutlookRank': 'MDL/StableX1X0|MRS/StableX1X0|MDL/StableX1X0',
#     'MarkItShortName': 'Intl Business Machs Corp',
#     'Rank': 2838909,
#     'SearchAllCategoryv2': 'Companies/Issuers',
#     'MXID': '100085757',
#     'SalesToReceivables': 3.056547,
#     'CountryHeadquartersName': 'United States',
#     'ForecastDividendCashflowRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBMDIVCF.N"/><a:Req value="145" scheme="IDN"/></a:Entity></a:Rship>',
#     'SearchAllCategoryv3': 'Companies/Issuers',
#     'TaxID': '130871985',
#     'MnaParentAcquirerCount': 0,
#     'TRBCHierarchicalCodeMeaning': 'IT Services & Consulting - NEC',
#     'PretaxProfit': 4837000000,
#     'UnderlyingEquityOptionIssueCount': 0,
#     'DocDateTime': '2022-04-22T15:35:38.000Z',
#     'RCSOrganisationTypeLeafML': 'ja 事業法人|zh-Hans 公司|zh-Hant 公司',
#     'SPsRatingsScope': [{'Agency': 'S&P',
#       'RatingType': 'SPI',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'OutlookRank': 0,
#       'RatingScope': 'F',
#       'Outlook': 'Stable'},
#      {'Agency': 'S&P',
#       'RatingType': 'SSU',
#       'CurrentRatingRank': 13,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SIS',
#       'CurrentRatingRank': 3,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SIS',
#       'CurrentRatingRank': 3,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SCP',
#       'CurrentRatingRank': 3,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SCP',
#       'CurrentRatingRank': 3,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SSU',
#       'CurrentRatingRank': 13,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'},
#      {'Agency': 'S&P',
#       'RatingType': 'SPI',
#       'CurrentRatingRank': 7,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'OutlookRank': 0,
#       'RatingScope': 'D',
#       'Outlook': 'Stable'},
#      {'Agency': 'S&P',
#       'RatingType': 'SMU',
#       'CurrentRatingRank': 0,
#       'CurrentRatingDate': '2011-05-13T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'F'},
#      {'Agency': 'S&P',
#       'RatingType': 'SMU',
#       'CurrentRatingRank': 13,
#       'CurrentRatingDate': '2021-05-06T00:00:00.000Z',
#       'Preliminary': 'n',
#       'Solicited': 'y',
#       'RatingScope': 'D'}],
#     'TRBCPrimaryCodeMeaning': 'IT Services & Consulting',
#     'OrgMainRepno': '4741N',
#     'AddressStateProvince': 'NEW YORK',
#     'TotalLiabilitiesUsd': 113005000000,
#     'RCSCountryHeadquartersGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'RevenueGrowthInterim': 7.659058,
#     'OAOrgType': 'COM',
#     'GicsLeaf': 'IT Consulting & Other Services',
#     'GeneralAliasNameJaHani': 'インターナショナル・ビジネス・マシーンズ',
#     'FDS': 'IBM',
#     'MarketCapitalisationIndices': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity rank="1"><a:Prop name="DisplayName" value="道琼斯工业平均指数" lang="zh-Hans"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="2"><a:Prop name="DisplayName" value="DJ工業株30種平均指数" lang="ja-Hani"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="3"><a:Prop name="DisplayName" value="DOW JONES INDU AVERAGE NDX" lang="en"/><a:Prop name="RIC" value=".DJI"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="4"><a:Prop name="DisplayName" value="DJ COMP AVERAGE" lang="en"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="5"><a:Prop name="DisplayName" value="道琼斯综合指数" lang="zh-Hans"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="6"><a:Prop name="DisplayName" value="DJ コンポジット平均" lang="ja-Hani"/><a:Prop name="RIC" value=".DJA"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="7"><a:Prop name="DisplayName" value="S&amp;P Composite 1500 Index" lang="en"/><a:Prop name="RIC" value=".SPSUP"/><a:Req value="5185" scheme="IDN"/><a:Req value="5775" scheme="IDN"/></a:Entity><a:Entity rank="8"><a:Prop name="DisplayName" value="DOW JONES GL TITAN 50 EUR NDX" lang="en"/><a:Prop name="RIC" value=".DJGTE"/><a:Req value="9822" scheme="IDN"/><a:Req value="7653" scheme="IDN"/></a:Entity><a:Entity rank="9"><a:Prop name="DisplayName" value="Refinitiv United States Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDUSP"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="10"><a:Prop name="DisplayName" value="Refinitiv North America Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNAPU"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="11"><a:Prop name="DisplayName" value="Refinitiv NAFTA Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDNFPU"/><a:Req value="7642" scheme="IDN"/></a:Entity><a:Entity rank="12"><a:Prop name="DisplayName" value="Refinitiv G7 Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDG7PU"/><a:Req value="3112" scheme="IDN"/></a:Entity><a:Entity rank="13"><a:Prop name="DisplayName" value="Refinitiv Global Price Return Index" lang="en"/><a:Prop name="RIC" value=".TRXFLDGLPU"/><a:Req value="3112" scheme="IDN"/></a:Entity></a:Rship>',
#     'ShareholdersEquity': 18901000000,
#     'PretaxProfitMargin': 0.084342,
#     'LegalNameJaKana': 'インターナショナルビジネスマシーンズコーポレーション',
#     'RCSOrganisationSubTypeLeaf': 'Company',
#     'IssuersUltimateParentHasCDS': True,
#     'IssuerHasCds': True,
#     'ListingStatus': 'LIS',
#     'ShareholdersEquityUsd': 18901000000,
#     'SucceededCompanyPrimaryRIC': 'KNXA.K^L12',
#     'FuturesCount': 22,
#     'DocumentTitleJaHani': 'インターナショナル･ビジネス･マシーンズ･コーポレーション, Public Company',
#     'RCSOrganisationSubTypeNameML': 'ja OA 組織サブタイプ\\法人|zh-Hans OA 组织子类型\\公司',
#     'SPsRatingType': 'Issuer/S&P/SPI|Issuer/S&P/SSU|Issuer/S&P/SIS|Issuer/S&P/SIS|Issuer/S&P/SCP|Issuer/S&P/SCP|Issuer/S&P/SSU|Issuer/S&P/SPI|Issuer/S&P/SMU|Issuer/S&P/SMU',
#     'SalesToInventory': 33.140711,
#     'EquityIndices': '.DJA~DLM~en:DJ COMP AVERAGE|DLM|.DJA~DLM~ja-Hani:DJ コンポジット平均|DLM|.DJA~DLM~zh-Hans:道琼斯综合指数|DLM|.DJGTE~DLM~en:DOW JONES GL TITAN 50 EUR NDX|DLM|.DJGT~DLM~en:Dow Jones Global Titans Index|DLM|.DJI~DLM~en:DOW JONES INDU AVERAGE NDX|DLM|.DJI~DLM~ja-Hani:DJ工業株30種平均指数|DLM|.DJI~DLM~zh-Hans:道琼斯工业平均指数|DLM|.DJUSTC~DLM~en:DOW JONES TECHNOLOGY NDX|DLM|.IVX~DLM~en:S&P 500 Value Index|DLM|.NYA~DLM~en:NYSE COMPOSITE|DLM|.NYA~DLM~ja-Hani:NYSE 総合指数|DLM|.OEXA~DLM~en:S&P 100 INDEX|DLM|.OEXA~DLM~ja-Hani:S&P 100種 指数|DLM|.OEXA~DLM~zh-Hans:标普100指数|DLM|.SPCOMIS~DLM~en:S&P Composite 1500 Software&Serv(IG)|DLM|.SPCOMITCS~DLM~en:S&P 1500 IT Services (Ind)|DLM|.SPCOMTKCS~DLM~en:S&P 1500 ITConsulting&Other Serv(SI)|DLM|.SPCOMT~DLM~en:S&P 1500 Info Technology (Sector)|DLM|.SPLGMID~DLM~en:S&P 900 INDEX|DLM|.SPLRCIS~DLM~en:S&P 500 Software & Services (IG)|DLM|.SPLRCITCS~DLM~en:S&P 500 IT Services (Industry)|DLM|.SPLRCTKCS~DLM~en:S&P 500 IT Consulting&Other Serv(SI)|DLM|.SPLRCT~DLM~en:S&P 500 Information Tech(Sector)|DLM|.SPLRCT~DLM~ja-Hani:S&P 500種 情報技術セクター指数|DLM|.SPLRCT~DLM~zh-Hans:标普信息技术指数|DLM|.SPSUP~DLM~en:S&P Composite 1500 Index|DLM|.SPX~DLM~en:S&P 500 INDEX|DLM|.SPX~DLM~ja-Hani:S&P 500 指数|DLM|.SPX~DLM~zh-Hans:标普500指数|DLM|.TRAFWLP1~DLM~en:Refinitiv StarMine Affinity World Leaders Price Return Index (USD)|DLM|.TRDIGXF~DLM~en:Refinitiv Global Large/Mid Diversity & Inclusion ex. Controversial Weapons Equal Weight Price|DLM|.TRENVUS1~DLM~en:Refinitiv/S-Network US Large Cap Environmental Best Practices Index (USD)|DLM|.TRENVUSE1~DLM~en:Refinitiv/S-Network US Large Cap Environmental Best Practices Index (EUR)|DLM|.TRESGQ1~DLM~en:RF IX GL ESG Equal Weighted PR|DLM|.TRESGUS1~DLM~en:Refinitiv/S-Network US Large Cap ESG Best Practices Index (USD)|DLM|.TRESGUSE1~DLM~en:Refinitiv/S-Network US Large Cap ESG Best Practices Index (EUR)|DLM|.TRESGZQ1~DLM~en:RF IX GL ESG HDLV Equal Weighted PR|DLM|.TRGEOSE1~DLM~en:Refinitiv Global Equal Opportunities Select Index|DLM|.TRSCUS1~DLM~en:Refinitiv/S-Network US Large Cap Social Best Practices Index (USD)|DLM|.TRSCUSE1~DLM~en:Refinitiv/S-Network US Large Cap Social Best Practices Index (EUR)|DLM|.TRX500USP~DLM~en:Refinitiv United States 500 Price Return Index|DLM|.TRXFLDAAPU~DLM~en:Refinitiv Americas Price Return Index|DLM|.TRXFLDAATL~DLM~en:RF AMERICAS TR LCY IDX|DLM|.TRXFLDG7PUSVIT~DLM~en:Refinitiv G7 IT Services & Consulting Price Return Index|DLM|.TRXFLDG7PUT21~DLM~en:Refinitiv G7 Software & IT Services-572010 Price Return Index|DLM|.TRXFLDG7PUT2~DLM~en:Refinitiv G7 Software & IT Services-5720 Price Return Index|DLM|.TRXFLDG7PUTEC~DLM~en:Refinitiv G7 Technology Price Return Index|DLM|.TRXFLDG7PU~DLM~en:Refinitiv G7 Price Return Index|DLM|.TRXFLDGAPUUSD~DLM~en:Refinitiv Global AUD Price Return Index (USD)|DLM|.TRXFLDGAPU~DLM~en:Refinitiv Global AUD Price Return Index (AUD)|DLM|.TRXFLDGATUUSD~DLM~en:Refinitiv Global AUD Total Return Index (USD)|DLM|.TRXFLDGDPUSVIT~DLM~en:Refinitiv Global Developed IT Services & Consulting Price Return Index|DLM|.TRXFLDGDPUT21~DLM~en:Refinitiv Global Developed Software & IT Services-572010 Price Return Index|DLM|.TRXFLDGDPUT2~DLM~en:Refinitiv Global Developed Software & IT Services-5720 Price Return Index|DLM|.TRXFLDGDPUTEC~DLM~en:Refinitiv Global Developed Technology Price Return Index|DLM|.TRXFLDGDPU~DLM~en:Refinitiv Global Developed Price Return Index|DLM|.TRXFLDGFPU~DLM~en:Refinitiv Global Ex Frontier Large and Mid Cap Price Return Index (USD)|DLM|.TRXFLDGLPUSVIT~DLM~en:Refinitiv Global IT Services & Consulting Price Return Index|DLM|.TRXFLDGLPUT21~DLM~en:Refinitiv Global Software & IT Services-572010 Price Return Index|DLM|.TRXFLDGLPUT2~DLM~en:Refinitiv Global Software & IT Services-5720 Price Return Index|DLM|.TRXFLDGLPUTEC~DLM~en:Refinitiv Global Technology Price Return Index|DLM|.TRXFLDGLPU~DLM~en:Refinitiv Global Price Return Index|DLM|.TRXFLDGLTL~DLM~en:RF GLOBAL TR LCY IDX|DLM|.TRXFLDGSPUUSD~DLM~en:Refinitiv Global Developed Ex Australia Price Return Index (USD ...
#     'RCSOrganisationTypeName': 'Corporation',
#     'MnaAcquirerCount': 0,
#     'SubsidiariesBondsCount': 349,
#     'MnaSellerCount': 0,
#     'ParentOrganisationName': 'International Business Machines Corp',
#     'ImpliedVolatilityRIC': '<a:Rship name="x" xmlns:a="http://www.reuters.com/ns/2007/10/31/webservices/SearchAndNavigation_1/NavCommonResponse_1"><a:Entity><a:Prop name="RIC" value="IBMATMIV.U"/><a:Req value="6410" scheme="IDN"/><a:Req value="4018" scheme="IDN"/></a:Entity></a:Rship>',
#     'RCSFilingCountryLeafML': 'ja 米国|zh-Hans 美国|zh-Hant 美國|es Estados Unidos|fr États Unis|ko 미국|ru США',
#     'OptionsCount': 1302,
#     'DocumentTitleJaKana': 'インターナショナルビジネスマシーンズコーポレーション, Public Company',
#     'RatingNameX1XRatingType': "Issuer|Issuer/FitchX1XFTC|Issuer/FitchX1XFTC/Fitch Long-term Issuer Default RatingX1XFDL|Issuer/Egan-Jones Ratings Co.X1XEGJ|Issuer/Egan-Jones Ratings Co.X1XEGJ/Egan-Jones Commercial PaperX1XEJC|Issuer/Moody'sX1XMDY|Issuer/Moody'sX1XMDY/Moody's Long-term Issuer RatingX1XMIS|Issuer/Moody'sX1XMDY/Moody's Senior UnsecuredX1XMSU|Issuer/Moody'sX1XMDY/Moody's Derived Long-term Issuer RatingX1XMDL|Issuer/FitchX1XFTC/Fitch Commercial PaperX1XFCP|Issuer/FitchX1XFTC/Fitch Short-term Issuer RatingX1XFSS|Issuer/FitchX1XFTC/Fitch Senior UnsecuredX1XFSU|Issuer/FitchX1XFTC/Fitch Long-term Senior Unsecured MTN RatingX1XFMU|Issuer/FitchX1XFTC/Fitch Short-term Debt RatingX1XFDT|Issuer/Moody'sX1XMDY/Moody's Long-term Senior Unsecured MTN RatingX1XMMU|Issuer/Moody'sX1XMDY/Moody's Commercial PaperX1XMCP|Issuer/Moody'sX1XMDY/Moody's Most Recent Short-term RatingX1XMRS|Issuer/Egan-Jones Ratings Co.X1XEGJ/Egan-Jones Senior UnsecuredX1XEJU|Issuer/FitchX1XFTC/Fitch Short-term Issuer Default RatingX1XFDS|Issuer/FitchX1XFTC/Fitch Long-term Issuer RatingX1XFIS",
#     'SponsorBondsExist': False,
#     'ICBSchemeName': 'Technology/Technology/Software & Computer Services/Computer Services',
#     'RCSOrganisationSubTypeGenealogy': 'M:1NJ\\OAOST:COR',
#     'REC': 'IBM',
#     'TRBC2012PrimaryCodeMeaning': 'Technology/Software & IT Services/Software & IT Services/IT Services & Consulting/IT Services & Consulting - NEC',
#     'RCSFilingCountryGenealogy': 'M:DQ\\G:AM\\G:6J|M:DQ\\G:AN\\G:6J|M:DH\\G:4\\G:9\\G:6J|M:DQ\\G:AQ\\G:6J|M:DQ\\G:AR\\G:6J|M:DQ\\G:AS\\G:6J|M:A9\\G:6J|M:DQ\\G:B9\\G:6J|M:1M2\\G:3U8\\G:3U9\\G:6J|M:DQ\\G:CX\\G:6J|M:DQ\\G:DE\\G:6J',
#     'SPsRatingX1XSPsRatingRank': 'SPI/A-X1X7|SSU/A-X1X13|SIS/A-2X1X3|SIS/A-2X1X3|SCP/A-2X1X3|SCP/A-2X1X3|SSU/A-X1X13|SPI/A-X1X7|SMU/NRX1X0|SMU/A-X1X13',
#     'CompositeDescriptiveNameZh': '国际商业机器公司|国际商用机器 國際商業機器公司',
#     'OrganisationType': 'CO',
#     'ICBScheme': '9533',
#     'SalesToAssets': 0.398303,
#     'UltimateParentOrganizationID': '4295904307',
#     'RCSCountryOfIncorporationLeaf': 'United States',
#     'EquitiesCount': 116,
#     'RCSOrganisationSubTypeLeafML': 'ja 法人|zh-Hans 公司',
#     'RCSPartyCountryLeaf': 'United States',
#     'CompositeDescriptiveName': 'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|International Business Machines Corp|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM',
#     'RevenueInterim': 14197000000,
#     'ActiveEstimatesExist': True,
#     'LegalName': 'INTERNATIONAL BUSINESS MACHINES CORPORATION',
#     'EquityDividends': -5869000000,
#     'BondsCount': 46,
#     'RCSOrganisationTypeLeaf': 'Corporation',
#     'CountryHeadquarters': 'USA',
#     'LEI': 'VGRQXHF3J8VDLUA7XE92',
#     'RCSOrganisationSubTypeName': 'OA Organization Subtype\\Company',
#     'CompositeDescriptiveNameJa': 'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ',
#     'MoodysIssuerRating': 'A3',
#     'Ebitda': 11555000000,
#     'ERRORS': ['VPIP CompanyOfficers',
#      'VPIP RCSCountryOfIncorporationGenealogy',
#      'VPIP GeneralAliasNameZhHans',
#      'VPIP CalaisAlias',
#      'VPIP GeneralAliasName',
#      'VPIP RCSFilingCountryName',
#      'VPIP RCSCountryHeadquartersName',
#      'VPIP LocalScheme',
#      'VPIP RCSCountryHeadquartersGenealogy',
#      'VPIP EquityIndices',
#      'VPIP RCSFilingCountryGenealogy']},
#    'copy_targets': {'symbol': ['18228',
#      'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'code': ['VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'namezh': ['国际商业机器公司|国际商用机器 國際商業機器公司'],
#     'SearchAllJa': ['事業法人',
#      'インタナショナル コーポレイション',
#      'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ'],
#     'RCSOriginalAccountsCurrencyGenealogy': ['C:6'],
#     'RCSOriginalAccountsCurrencyNameML': ['ja 米ドル|zh-Hans 美元|zh-Hant 美元'],
#     'name': ['internatnl INTL intrnl',
#      'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|International Business Machines Corp|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM'],
#     'SearchAllSymbol': ['18228',
#      'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'SearchAllZh': ['公司', '国际商业机器公司|国际商用机器 國際商業機器公司'],
#     'RCSOriginalAccountsCurrencyName': ['US Dollar'],
#     'LookupAllSymbol': ['18228',
#      'VGRQXHF3J8VDLUA7XE92 US4592001014 0000051143 4295904307 459200101 49EB20 IBM'],
#     'nameja': ['インタナショナル コーポレイション',
#      'インターナショナル･ビジネス･マシーンズ･コーポレーション インターナショナルビジネスマシーンズコーポレーション いんたーなしょなるびじねすましーんずこーぽれーしょん インターナショナル・ビジネス・マシーンズ'],
#     'SearchAllText': ['internatnl INTL intrnl',
#      'IT Services & Consulting (NEC) ORGANISATION Corporation Listed',
#      'Big Blue|Guo Ji Shang Ye Ji Qi Gong Si|Guo Ji Shang Yong Ji Qi|IBM|Intanashonaru Bijinesu Mashinzu|International Business Machines|International Business Machines Corp|Software Artistry Inc|Unison Software Inc INTERNATIONAL BUSINESS MACHINES CORPORATION International Business Machines Corp IBM']}}]}

# %% [markdown]
# #### Special Properties
# The Search service includes a number of special properties that enhance the ability to find meaningful results. In addition to the special property *_debugall* used within the **select** parameter as outlined above, the following properties are available:

# %%
# The 'code' specification will search across all codes, such as RICs, tickers, SEDOLs etc.  
# Primarily used within a filter but can be used as a selectable property.
response=search.Definition(
    filter = "code eq 'IBM'"
).get_data()
response.data.df
# Out:
#   BusinessEntity  \
# 0   ORGANISATION
# 1   QUOTExEQUITY
# 2   QUOTExEQUITY
# 3   QUOTExEQUITY
# 4   QUOTExEQUITY
# 5   QUOTExEQUITY
# 6   QUOTExEQUITY
# 7   QUOTExEQUITY
# 8   QUOTExEQUITY
# 9   QUOTExEQUITY
#
#                                                                                  DocumentTitle  \
# 0                                         International Business Machines Corp, Public Company
# 1                      International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 2   International Business Machines Corp, Ordinary Share, MiFID Composite Cross Market Service
# 3   International Business Machines Corp, Ordinary Share, MiFID Composite Cross Market Service
# 4  International Business Machines Corp, Depository Receipt, Bolsa de Comercio de Buenos Aires
# 5                International Business Machines Corp, Ordinary Share, New York Stock Exchange
# 6                     International Business Machines Corp, Ordinary Share, NASDAQ INTERMARKET
# 7                              International Business Machines Corp, Ordinary Share, NYSE Arca
# 8                     International Business Machines Corp, Ordinary Share, Cboe EDGX Exchange
# 9                      International Business Machines Corp, Ordinary Share, Cboe BZX Exchange
#
#         PermID         PI         RIC
# 0         <NA>      37036        <NA>
# 1  55839165994    1097326         IBM
# 2  21475739068   79345498  IBMEUR.xbo
# 3  21523029548  131770829  IBMUSD.xbo
# 4  55838283585    1006058      IBM.BA
# 5  55838323096    1090370       IBM.N
# 6  55835333953     765744      IBM.TH
# 7  55837129318     753753       IBM.P
# 8  21475059739   73533774      IBM.DG
# 9  55845629228   53703996       IBM.Z

# %%
# The 'name' specification will search across all names, such as common name, legal name, issuer name, etc. 
# Primarily used within a filter but can be used as a selectable property.
response=search.Definition(
    filter = "name eq 'IBM'",
).get_data()
response.data.df
# Out:
#   BusinessEntity  \
# 0   ORGANISATION
# 1   ORGANISATION
# 2   QUOTExEQUITY
# 3   ORGANISATION
# 4   QUOTExEQUITY
# 5   QUOTExEQUITY
# 6   QUOTExEQUITY
# 7   QUOTExEQUITY
# 8   QUOTExEQUITY
# 9   QUOTExEQUITY
#
#                                                                                                 DocumentTitle  \
# 0                                                        International Business Machines Corp, Public Company
# 1                                                                               Banco IBM SA, Private Company
# 2                                     International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 3                           Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 4              Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
# 5              Euronext Amsterdam IBM Dividend Future Chain Contracts, Equity Future, USD, Euronext Amsterdam
# 6               Eurex International Business Machines Equity Future Continuation 1, Equity Future, USD, Eurex
# 7               Eurex International Business Machines Equity Future Continuation 2, Equity Future, USD, Eurex
# 8  Euronext Amsterdam IBM Single Stock Dividend Future Continuation 1, Equity Future, USD, Euronext Amsterdam
# 9               Eurex International Business Machines Equity Future Continuation 3, Equity Future, USD, Eurex
#
#         PermID         PI       RIC
# 0         <NA>      37036      <NA>
# 1         <NA>      76208      <NA>
# 2  55839165994    1097326       IBM
# 3         <NA>   18062670      <NA>
# 4  21481052421   48924732   0#IBMF:
# 5  21612423771  259118763  0#IBMDF:
# 6  21481052892   49450681    IBMFc1
# 7  21481053949   50092347    IBMFc2
# 8  21613372305  260213021   IBMDFc1
# 9  21481053950   50092348    IBMFc3

# %%
# The special character underscore (_) is a convenient token that can be used to select the default Properties.  
# This will allow users to quickly select the default values plus any other properties when testing out your search.
response=search.Definition(
    query = "IBM",
    top = 5,
    #filter = "SearchAllCategoryv3 eq 'Options'",
    select = "_, SearchAllCategoryv3"
).get_data()
response.data.df
# Out:
#   BusinessEntity  \
# 0   ORGANISATION
# 1   ORGANISATION
# 2   QUOTExEQUITY
# 3   ORGANISATION
# 4   QUOTExEQUITY
#
#                                                                                     DocumentTitle  \
# 0                                            International Business Machines Corp, Public Company
# 1                                                                   Banco IBM SA, Private Company
# 2                         International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 3               Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 4  Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
#
#         PermID        PI      RIC SearchAllCategoryv3
# 0         <NA>     37036     <NA>   Companies/Issuers
# 1         <NA>     76208     <NA>   Companies/Issuers
# 2  55839165994   1097326      IBM            Equities
# 3         <NA>  18062670     <NA>   Companies/Issuers
# 4  21481052421  48924732  0#IBMF:             Futures

# %%
# DocumentTitle
# As you've seen in some of the above output, this property is on by default when you want to display your search results.  
# The DocumentTitle property is a quick way to describe the content retrieved for each matching document.  
# It is made up of the following child properties: 
#    'DTSubjectName', 'DTSimpleType', 'DTSource', and 'DTCharacteristics'.
response=search.Definition(
    query = "IBM",
    top = 5,
    select = "DocumentTitle, DTSubjectName, DTSimpleType, DTSource, DTCharacteristics"
).get_data()
response.data.df
# Out:
#                                                                                     DocumentTitle  \
# 0                                            International Business Machines Corp, Public Company
# 1                                                                   Banco IBM SA, Private Company
# 2                         International Business Machines Corp, Ordinary Share, NYSE Consolidated
# 3               Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4, Private Company
# 4  Eurex International Business Machines Equity Future Chain Contract , Equity Future, USD, Eurex
#
#                                                         DTSubjectName  \
# 0                                International Business Machines Corp
# 1                                                        Banco IBM SA
# 2                                International Business Machines Corp
# 3    Tiers Corporate Bond Backed Certificates Trust Series Ibm 1997 4
# 4  Eurex International Business Machines Equity Future Chain Contract
#
#       DTSimpleType           DTSource DTCharacteristics
# 0   Public Company               <NA>              <NA>
# 1  Private Company               <NA>              <NA>
# 2   Ordinary Share  NYSE Consolidated              <NA>
# 3  Private Company               <NA>              <NA>
# 4    Equity Future              Eurex               USD

# %% [markdown]
# #### Navigators - List all available categories

# %%
response=search.Definition(
    top = 0,
    navigators = "SearchAllCategoryv3"
).get_data()
response.data.raw["Navigators"]["SearchAllCategoryv3"]["Buckets"]
# Out:
# [{'Label': 'Other Quote', 'Count': 72429185},
#  {'Label': 'Companies/Issuers', 'Count': 11822365},
#  {'Label': 'Warrants', 'Count': 11769316},
#  {'Label': 'Commodities', 'Count': 10546329},
#  {'Label': 'Bond Pricing', 'Count': 9390388},
#  {'Label': 'Bonds', 'Count': 9145531},
#  {'Label': 'Options', 'Count': 4411014},
#  {'Label': 'US Municipal Bonds', 'Count': 4382416},
#  {'Label': 'Equities', 'Count': 4072551},
#  {'Label': 'Exchange-Traded Rates', 'Count': 3375129},
#  {'Label': 'Futures', 'Count': 3133065},
#  {'Label': 'Other Instrument', 'Count': 2947547},
#  {'Label': 'Mortgage Backed Securities', 'Count': 2802928},
#  {'Label': 'Officers', 'Count': 2599056},
#  {'Label': 'FX & Money', 'Count': 2283177},
#  {'Label': 'Commercial Papers', 'Count': 2021762},
#  {'Label': 'Funds', 'Count': 1931017},
#  {'Label': 'Mergers & Acquisitions', 'Count': 1364493},
#  {'Label': 'OTC Interest Rate Derivatives', 'Count': 1193369},
#  {'Label': 'CMO & ABS', 'Count': 996348},
#  {'Label': 'Commodities Physical Assets', 'Count': 574730},
#  {'Label': 'Economic Indicators', 'Count': 442291},
#  {'Label': 'Indices', 'Count': 426073},
#  {'Label': 'Credit Default Swaps', 'Count': 260377},
#  {'Label': 'Fixed Income Curves', 'Count': 146601},
#  {'Label': 'Analyst', 'Count': 134005},
#  {'Label': 'People', 'Count': 114127},
#  {'Label': 'Loans', 'Count': 85219},
#  {'Label': 'Buy Side Contact', 'Count': 70169},
#  {'Label': 'Bond Repos', 'Count': 62442},
#  {'Label': 'Fund Manager', 'Count': 56570},
#  {'Label': 'ABS & CMO', 'Count': 33408},
#  {'Label': 'Zero Curves', 'Count': 24512},
#  {'Label': 'Sell Side Contact', 'Count': 15331},
#  {'Label': 'Government Benchmarks', 'Count': 8385},
#  {'Label': 'Credit Default Swap Index Pricing', 'Count': 8132},
#  {'Label': 'Reuters Polls', 'Count': 4178},
#  {'Label': 'Credit Default Swap Indices', 'Count': 2005},
#  {'Label': 'Market Tools', 'Count': 1809},
#  {'Label': 'Help and FAQs', 'Count': 1091}]

# %% [markdown]
# #### Common Properties
# As you become more familiar with search, you will soon recognize there will be a number of very useful properties that will act as your "go-tos" when filtering or selecting fields.

# %% [markdown]
# #### Common Properties - RCS (Reuters Classification Scheme)
# Throughout many documents, you will notice a number of RCS fields that are popular when selecting and filtering.
#
# *Note* - I'll use navigators to demonstrate the values of these common properties.

# %%
# RCSAssetCategoryLeaf
# Specific to assets, this property will categorize the results into a readable identifier such as: 'Bond', 
# 'Commodity Future', 'Commercial Paper', etc.  Where the property SearchAllCategoryv3 provides general categories, 
# this property will be more specific to assets.  Pull out the top 10.
response = search.Definition(
    top = 0,
    navigators = "RCSAssetCategoryLeaf(buckets:10)"
).get_data()
response.data.raw["Navigators"]["RCSAssetCategoryLeaf"]["Buckets"]
# Out:
# [{'Label': 'Barrier Warrant', 'Count': 21583549},
#  {'Label': 'Bond', 'Count': 17334513},
#  {'Label': 'Commodity Future', 'Count': 5020617},
#  {'Label': 'Traditional Warrant', 'Count': 4615324},
#  {'Label': 'Equity Cash Option', 'Count': 3800611},
#  {'Label': 'Interest Rate Future Spread', 'Count': 3187273},
#  {'Label': 'Commodity Spread', 'Count': 2888002},
#  {'Label': 'Equity Future', 'Count': 2827417},
#  {'Label': 'Mortgage-Backed Security', 'Count': 2826845},
#  {'Label': 'Certificate of Deposit', 'Count': 2416895}]

# %%
# RCSTRBC2012Leaf
# Represents the industry sector.  For example, if I query for Apple Computers, I will get many different industry sectors such as: 
# 'Computer Hardware (NEC)', 'Laptop & Desktop Computers', 'Phones & Smart Phones', etc.
response = search.Definition(
    top = 0,
    navigators = "RCSTRBC2012Leaf(buckets:20)"
).get_data()
response.data.raw["Navigators"]["RCSTRBC2012Leaf"]["Buckets"]
# Out:
# [{'Label': 'Banks (NEC)', 'Count': 4355597},
#  {'Label': 'Corporate Financial Services (NEC)', 'Count': 3145917},
#  {'Label': 'Corporate Banks', 'Count': 1453140},
#  {'Label': 'Retail & Mortgage Banks', 'Count': 1305023},
#  {'Label': 'Investment Banking & Brokerage Services (NEC)', 'Count': 753165},
#  {'Label': 'Public Finance Activities', 'Count': 667740},
#  {'Label': 'Government & Government Finance (NEC)', 'Count': 421280},
#  {'Label': 'Consumer Lending (NEC)', 'Count': 418007},
#  {'Label': 'Investment Holding Companies (NEC)', 'Count': 387959},
#  {'Label': 'Investment Management & Fund Operators (NEC)', 'Count': 361237},
#  {'Label': 'Construction & Engineering (NEC)', 'Count': 346107},
#  {'Label': 'Electric Utilities (NEC)', 'Count': 310131},
#  {'Label': 'Wealth Management', 'Count': 302200},
#  {'Label': 'Diversified Investment Services', 'Count': 290818},
#  {'Label': 'Professional Information Services (NEC)', 'Count': 276101},
#  {'Label': 'Real Estate Rental, Development & Operations (NEC)',
#   'Count': 273516},
#  {'Label': 'Business Support Services (NEC)', 'Count': 270035},
#  {'Label': 'Building Contractors', 'Count': 205102},
#  {'Label': 'Financial & Commodity Market Operators & Service Providers (NEC)',
#   'Count': 180307},
#  {'Label': 'Management Consulting Services', 'Count': 164277}]

# %%
# Industry Sector
# RCSTRBC2012Leaf
# RCSTRBC2012Genealogy
# RCSTRBC2012Name
# Provide a breakdown of the hierarchy defined for many of these RCS attributes.  You can see the mapping between the 
# hierarchy defined with the Genealogy property and Name property.  
# For example, the code 'B:262' maps to the name 'Banking & Investment Services'.

#phrase = '"Construction Materials"'
#phrase = '"Pharmaceuticals & Medical Research"'

response = search.Definition(
    #filter = f"RCSTRBC2012Name eq '{phrase}'",    # Use eq to find embedded phrase
    #filter = "startswith(RCSTRBC2012Name, 'Financials\\\\Banking & Investment Services\\\\Investment Banking')",
    top = 0,
    navigators = "RCSTRBC2012Leaf(buckets:10), RCSTRBC2012Genealogy(buckets:10), RCSTRBC2012Name"
).get_data()
response.data.raw['Navigators']
# Out:
# {'RCSTRBC2012Genealogy': {'Buckets': [{'Label': 'B:261\\B:262\\B:127\\B:128\\B:1615',
#     'Count': 4355596},
#    {'Label': 'B:261\\B:262\\B:127\\B:131\\B:1627', 'Count': 3145917},
#    {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1616', 'Count': 1453041},
#    {'Label': 'B:261\\B:262\\B:127\\B:128\\B:1617', 'Count': 1300752},
#    {'Label': 'B:261\\B:262\\B:263\\B:207\\B:1633', 'Count': 743229},
#    {'Label': 'B:310\\B:311\\B:312\\B:313\\B:1889', 'Count': 664928},
#    {'Label': 'B:310\\B:311\\B:312\\B:313\\B:1888', 'Count': 421280},
#    {'Label': 'B:261\\B:262\\B:127\\B:129\\B:1621', 'Count': 410683},
#    {'Label': 'B:261\\B:264\\B:265\\B:266\\B:1652', 'Count': 387959},
#    {'Label': 'B:261\\B:262\\B:263\\B:208\\B:1639', 'Count': 361237}]},
#  'RCSTRBC2012Leaf': {'Buckets': [{'Label': 'Banks (NEC)', 'Count': 4355596},
#    {'Label': 'Corporate Financial Services (NEC)', 'Count': 3145917},
#    {'Label': 'Corporate Banks', 'Count': 1453041},
#    {'Label': 'Retail & Mortgage Banks', 'Count': 1300752},
#    {'Label': 'Investment Banking & Brokerage Services (NEC)', 'Count': 743229},
#    {'Label': 'Public Finance Activities', 'Count': 664928},
#    {'Label': 'Government & Government Finance (NEC)', 'Count': 421280},
#    {'Label': 'Consumer Lending (NEC)', 'Count': 410683},
#    {'Label': 'Investment Holding Companies (NEC)', 'Count': 387959},
#    {'Label': 'Investment Management & Fund Operators (NEC)',
#     'Count': 361237}]},
#  'RCSTRBC2012Name': {'Buckets': [{'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Banks (NEC)',
#     'Count': 4355596},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Corporate Financial Services\\Corporate Financial Services (NEC)',
#     'Count': 3145917},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Corporate Banks',
#     'Count': 1453141},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Banks\\Retail & Mortgage Banks',
#     'Count': 1305084},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Banking & Brokerage Services\\Investment Banking & Brokerage Services (NEC)',
#     'Count': 753197},
#    {'Label': 'Government Activity\\Government Activity\\Government Activity\\Government & Government Finance\\Public Finance Activities',
#     'Count': 668144},
#    {'Label': 'Government Activity\\Government Activity\\Government Activity\\Government & Government Finance\\Government & Government Finance (NEC)',
#     'Count': 421321},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Consumer Lending\\Consumer Lending (NEC)',
#     'Count': 418007},
#    {'Label': 'Financials\\Investment Holding Companies\\Investment Holding Companies\\Investment Holding Companies\\Investment Holding Companies (NEC)',
#     'Count': 387959},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Management & Fund Operators\\Investment Management & Fund Operators (NEC)',
#     'Count': 361237},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Construction & Engineering (NEC)',
#     'Count': 346107},
#    {'Label': 'Utilities\\Utilities\\Electric Utilities & IPPs\\Electric Utilities\\Electric Utilities (NEC)',
#     'Count': 310132},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Management & Fund Operators\\Wealth Management',
#     'Count': 303720},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Diversified Investment Services\\Diversified Investment Services',
#     'Count': 290818},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Professional Information Services\\Professional Information Services (NEC)',
#     'Count': 277023},
#    {'Label': 'Real Estate\\Real Estate\\Real Estate Operations\\Real Estate Rental, Development & Operations\\Real Estate Rental, Development & Operations (NEC)',
#     'Count': 273516},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Business Support Services\\Business Support Services (NEC)',
#     'Count': 270035},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Building Contractors',
#     'Count': 207216},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Financial & Commodity Market Operators & Service Providers\\Financial & Commodity Market Operators & Service Providers (NEC)',
#     'Count': 180365},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Business Support Services\\Management Consulting Services',
#     'Count': 165831},
#    {'Label': 'Technology\\Software & IT Services\\Software & IT Services\\Software\\Software (NEC)',
#     'Count': 158841},
#    {'Label': 'Technology\\Software & IT Services\\Software & IT Services\\IT Services & Consulting\\IT Services & Consulting (NEC)',
#     'Count': 147083},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Banking & Brokerage Services\\Investment Banking',
#     'Count': 145362},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Management & Fund Operators\\Investment Management',
#     'Count': 124512},
#    {'Label': 'Consumer Non-Cyclicals\\Food & Drug Retailing\\Food & Drug Retailing\\Food Retail & Distribution\\Supermarkets & Convenience Stores',
#     'Count': 109410},
#    {'Label': 'Healthcare\\Pharmaceuticals & Medical Research\\Pharmaceuticals\\Pharmaceuticals\\Pharmaceuticals (NEC)',
#     'Count': 108443},
#    {'Label': 'Real Estate\\Real Estate\\Real Estate Operations\\Real Estate Services\\Real Estate Services (NEC)',
#     'Count': 107436},
#    {'Label': 'Government Activity\\Government Activity\\Government Activity\\Government Administration Activities\\Government Administration Activities',
#     'Count': 95377},
#    {'Label': 'Consumer Cyclicals\\Retailers\\Specialty Retailers\\Auto Vehicles, Parts & Service Retailers\\Auto Vehicles, Parts & Service Retailers (NEC)',
#     'Count': 95059},
#    {'Label': 'Technology\\Telecommunications Services\\Telecommunications Services\\Integrated Telecommunications Services\\Integrated Telecommunications Services (NEC)',
#     'Count': 94502},
#    {'Label': 'Industrials\\Industrial Goods\\Machinery, Tools, Heavy Vehicles, Trains & Ships\\Industrial Machinery & Equipment\\Industrial Machinery & Equipment (NEC)',
#     'Count': 92827},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Banking & Brokerage Services\\Brokerage Services',
#     'Count': 91456},
#    {'Label': 'Healthcare\\Healthcare Services & Equipment\\Healthcare Providers & Services\\Healthcare Facilities & Services\\Hospitals, Clinics & Primary Care Services',
#     'Count': 88070},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Consumer Lending\\Consumer Leasing',
#     'Count': 86502},
#    {'Label': 'Basic Materials\\Chemicals\\Chemicals\\Commodity Chemicals\\Commodity Chemicals (NEC)',
#     'Count': 86495},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Oil & Gas\\Oil & Gas Exploration and Production\\Oil & Gas Exploration and Production (NEC)',
#     'Count': 85866},
#    {'Label': 'Financials\\Collective Investments\\Collective Investments\\UK Investment Trusts\\UK Investment Trusts',
#     'Count': 83471},
#    {'Label': 'Academic & Educational Services\\Academic & Educational Services\\Miscellaneous Educational Service Providers\\Miscellaneous Educational Service Providers\\Miscellaneous Educational Service Providers',
#     'Count': 82628},
#    {'Label': 'Consumer Non-Cyclicals\\Food & Beverages\\Food & Tobacco\\Food Processing\\Food Processing (NEC)',
#     'Count': 81037},
#    {'Label': 'Financials\\Insurance\\Insurance\\Multiline Insurance & Brokers\\Insurance Brokers',
#     'Count': 76850},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Services\\Hotels & Entertainment Services\\Restaurants & Bars\\Restaurants & Bars (NEC)',
#     'Count': 73150},
#    {'Label': 'Basic Materials\\Mineral Resources\\Construction Materials\\Construction Materials\\Construction Materials (NEC)',
#     'Count': 65327},
#    {'Label': 'Utilities\\Utilities\\Multiline Utilities\\Multiline Utilities\\Multiline Utilities',
#     'Count': 64642},
#    {'Label': 'Financials\\Investment Holding Companies\\Investment Holding Companies\\Investment Holding Companies\\Shell Companies',
#     'Count': 62618},
#    {'Label': 'Real Estate\\Real Estate\\Real Estate Operations\\Real Estate Rental, Development & Operations\\Office Real Estate Rental & Development',
#     'Count': 62085},
#    {'Label': 'Consumer Cyclicals\\Automobiles & Auto Parts\\Automobiles & Auto Parts\\Auto, Truck & Motorcycle Parts\\Auto, Truck & Motorcycle Parts (NEC)',
#     'Count': 61709},
#    {'Label': 'Industrials\\Industrial Goods\\Machinery, Tools, Heavy Vehicles, Trains & Ships\\Industrial Machinery & Equipment\\Industrial Machinery',
#     'Count': 61608},
#    {'Label': 'Industrials\\Industrial Goods\\Machinery, Tools, Heavy Vehicles, Trains & Ships\\Electrical Components & Equipment\\Electrical Components & Equipment (NEC)',
#     'Count': 61575},
#    {'Label': 'Healthcare\\Pharmaceuticals & Medical Research\\Biotechnology & Medical Research\\Biotechnology & Medical Research\\Biotechnology & Medical Research (NEC)',
#     'Count': 57555},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Products\\Homebuilding & Construction Supplies\\Homebuilding\\Residential Builders - Single Homes',
#     'Count': 55987},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Services\\Hotels & Entertainment Services\\Hotels, Motels & Cruise Lines\\Hotels & Motels',
#     'Count': 55807},
#    {'Label': 'Industrials\\Transportation\\Freight & Logistics Services\\Ground Freight & Logistics\\Freight Trucking',
#     'Count': 55794},
#    {'Label': 'Financials\\Insurance\\Insurance\\Life & Health Insurance\\Life & Health Insurance (NEC)',
#     'Count': 53507},
#    {'Label': 'Financials\\Banking & Investment Services\\Investment Banking & Investment Services\\Investment Management & Fund Operators\\Hedge Funds',
#     'Count': 52572},
#    {'Label': 'Basic Materials\\Mineral Resources\\Metals & Mining\\Iron & Steel\\Iron & Steel (NEC)',
#     'Count': 51587},
#    {'Label': 'Financials\\Collective Investments\\Collective Investments\\Closed End Funds\\Closed End Funds',
#     'Count': 50177},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Highway & Bridge Construction',
#     'Count': 50095},
#    {'Label': 'Healthcare\\Healthcare Services & Equipment\\Healthcare Providers & Services\\Healthcare Facilities & Services\\Healthcare Facilities & Services (NEC)',
#     'Count': 50050},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Oil & Gas\\Oil & Gas Refining and Marketing\\Oil & Gas Refining and Marketing (NEC)',
#     'Count': 49056},
#    {'Label': 'Basic Materials\\Mineral Resources\\Metals & Mining\\Iron & Steel\\Metallic Rolling & Drawing Products',
#     'Count': 49006},
#    {'Label': 'Basic Materials\\Mineral Resources\\Metals & Mining\\Iron & Steel\\Metal Service Centers',
#     'Count': 48868},
#    {'Label': 'Basic Materials\\Chemicals\\Chemicals\\Commodity Chemicals\\Plastics',
#     'Count': 48363},
#    {'Label': 'Consumer Non-Cyclicals\\Food & Drug Retailing\\Food & Drug Retailing\\Drug Retailers\\Drug Retailers (NEC)',
#     'Count': 46420},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Products\\Homebuilding & Construction Supplies\\Construction Supplies & Fixtures\\Plumbing Fixtures & Fittings',
#     'Count': 45486},
#    {'Label': 'Consumer Non-Cyclicals\\Personal & Household Products & Services\\Personal & Household Products & Services\\Personal Services\\Personal Services (NEC)',
#     'Count': 45398},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Corporate Financial Services\\Commercial Loans',
#     'Count': 45111},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Products\\Homebuilding & Construction Supplies\\Homebuilding\\Homebuilding (NEC)',
#     'Count': 44775},
#    {'Label': 'Consumer Non-Cyclicals\\Consumer Goods Conglomerates\\Consumer Goods Conglomerates\\Consumer Goods Conglomerates\\Consumer Goods Conglomerates',
#     'Count': 44227},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Oil & Gas Related Equipment and Services\\Oil & Gas Transportation Services\\Oil & Gas Transportation Services (NEC)',
#     'Count': 42339},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Coal\\Coal\\Coal (NEC)',
#     'Count': 42246},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Civil Engineers & Architects',
#     'Count': 42205},
#    {'Label': 'Basic Materials\\Mineral Resources\\Metals & Mining\\Diversified Mining\\Diversified Mining',
#     'Count': 42077},
#    {'Label': 'Industrials\\Transportation\\Passenger Transportation Services\\Passenger Transportation, Ground & Sea\\Passenger Transportation, Ground & Sea (NEC)',
#     'Count': 42004},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Oil & Gas\\Oil & Gas Refining and Marketing\\Gasoline Stations',
#     'Count': 41983},
#    {'Label': 'Energy\\Energy - Fossil Fuels\\Oil & Gas\\Oil & Gas Refining and Marketing\\Petroleum Refining',
#     'Count': 40789},
#    {'Label': 'Technology\\Technology Equipment\\Semiconductors & Semiconductor Equipment\\Semiconductors\\Semiconductors (NEC)',
#     'Count': 40123},
#    {'Label': 'Technology\\Telecommunications Services\\Telecommunications Services\\Wireless Telecommunications Services\\Wireless Telecommunications Services (NEC)',
#     'Count': 40044},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Land Division & Subdivision',
#     'Count': 39778},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Business Support Services\\Maintenance & Repair Services',
#     'Count': 39629},
#    {'Label': 'Healthcare\\Healthcare Services & Equipment\\Healthcare Equipment & Supplies\\Medical Equipment, Supplies & Distribution\\Medical Equipment, Supplies & Distribution (NEC)',
#     'Count': 39501},
#    {'Label': 'Real Estate\\Real Estate\\Real Estate Operations\\Real Estate Rental, Development & Operations\\Residential Real Estate Rental & Development',
#     'Count': 38631},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Environmental Services & Equipment\\Waste Management, Disposal & Recycling Services',
#     'Count': 38214},
#    {'Label': 'Financials\\Banking & Investment Services\\Banking Services\\Corporate Financial Services\\Commercial Leasing',
#     'Count': 37431},
#    {'Label': 'Financials\\Insurance\\Insurance\\Property & Casualty Insurance\\Property & Casualty Insurance (NEC)',
#     'Count': 36943},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Professional & Commercial Services\\Business Support Services\\Legal Services',
#     'Count': 36223},
#    {'Label': 'Technology\\Software & IT Services\\Software & IT Services\\Online Services\\Online Services (NEC)',
#     'Count': 36025},
#    {'Label': 'Utilities\\Utilities\\Natural Gas Utilities\\Natural Gas Utilities\\Natural Gas Distribution',
#     'Count': 35238},
#    {'Label': 'Consumer Non-Cyclicals\\Personal & Household Products & Services\\Personal & Household Products & Services\\Personal Products\\Personal Products (NEC)',
#     'Count': 34975},
#    {'Label': 'Basic Materials\\Mineral Resources\\Construction Materials\\Construction Materials\\Cement & Concrete Manufacturing',
#     'Count': 34897},
#    {'Label': 'Industrials\\Transportation\\Freight & Logistics Services\\Ground Freight & Logistics\\Ground Freight & Logistics (NEC)',
#     'Count': 34873},
#    {'Label': 'Healthcare\\Pharmaceuticals & Medical Research\\Biotechnology & Medical Research\\Biotechnology & Medical Research\\Bio Therapeutic Drugs',
#     'Count': 33559},
#    {'Label': 'Real Estate\\Real Estate\\Residential & Commercial REITs\\Commercial REITs\\Commercial REITs (NEC)',
#     'Count': 33522},
#    {'Label': 'Consumer Non-Cyclicals\\Personal & Household Products & Services\\Personal & Household Products & Services\\Personal Services\\Child Care & Family Services',
#     'Count': 32631},
#    {'Label': 'Industrials\\Industrial & Commercial Services\\Construction & Engineering\\Construction & Engineering\\Commercial Buildings',
#     'Count': 32414},
#    {'Label': 'Technology\\Technology Equipment\\Communications & Networking\\Communications & Networking\\Communications & Networking (NEC)',
#     'Count': 32360},
#    {'Label': 'Basic Materials\\Mineral Resources\\Metals & Mining\\Gold\\Gold Mining',
#     'Count': 32118},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Services\\Media & Publishing\\Advertising & Marketing\\Advertising Agency',
#     'Count': 32018},
#    {'Label': 'Utilities\\Utilities\\Natural Gas Utilities\\Natural Gas Utilities\\Natural Gas Utilities (NEC)',
#     'Count': 32004},
#    {'Label': 'Consumer Non-Cyclicals\\Food & Beverages\\Food & Tobacco\\Fishing & Farming\\Grain (Crop) Production',
#     'Count': 31965},
#    {'Label': 'Consumer Cyclicals\\Cyclical Consumer Services\\Media & Publishing\\Broadcasting\\Broadcasting (NEC)',
#     'Count': 31937}]}}

# %% [markdown]
# The above output includes 3 separate sections: RCSTRBC2012Genealogy, RCSTRBC2012Leaf and RCSTRBC2012Name.  For each you can see a breakdown ot the buckets.

# %%
rd.close_session()
